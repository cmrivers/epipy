# %% [markdown]
# # Basic transmission tree builder
#
# * Caitlin Rivers
#
# * Virginia Bioinformatics Institute at Virginia Tech
#
# * cmrivers@vbi.vt.edu
#
# -------
#
# Given a line listing with dates and basic information about cluster membership, this script will estimate who transmitted an infectious disease to whom based on case onset dates.
#
# Wish list for improvements:
#
# * Make algorithm that determines who infected whom more sophisticated.
#
# * Find a way to keep single cases (e.g. those not part of a cluster) in the data set so they can be plotted on the casetree.
#
# * Fix plot_cluster() function so it is functional.

# %%
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime, timedelta
import pandas as pd

# %%
def date_convert(x):
    """ Convert dates to datetime object
    """
    try:
        y = datetime.strptime(x, "%Y-%m-%d")
    except:
        y = np.nan
        
    return y

# %% [markdown]
# Data (from 2013 MERS outbreak) are available in cmrivers/epipy repo on Github.

# %%
dat = pd.read_csv("../Line list & epi stats - Line list.csv", parse_dates=True)
dat['Cluster ID'] = dat['Cluster ID'].replace(np.nan, 'single')
dat.index = dat['Cluster ID']

# %%
dat
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, hospital A to single
# Data columns (total 14 columns):
# Case #                      181  non-null values
# Approx onset date           80  non-null values
# Approx reporting date       103  non-null values
# Age                         172  non-null values
# Sex                         159  non-null values
# Probable infection place    180  non-null values
# Health status               178  non-null values
# Approx death date           42  non-null values
# Region                      130  non-null values
# HCW                         26  non-null values
# Reported comorbidities      88  non-null values
# Cluster ID                  182  non-null values
# Notes                       33  non-null values
#  Zoonotic                   154  non-null values
# dtypes: float64(2), object(12)

# %%
dat['onset_date'] = dat['Approx onset date'].map(date_convert)
dat['report_date'] = dat['Approx reporting date'].map(date_convert)
dat['dates'] = dat['onset_date'].combine_first(dat['report_date']) #combines onset and report date columns, with onset date preferential

# %%
def _group_clusters(df, cluster_id, date_col):
    ''' Use pandas to group clusters by basic cluster membership information
    df = pandas dataframe
    cluster_id = column that identifies cluster membership, which can be a basic string like "hospital cluster A"
    date_col = onset or report date column
    '''
    clusters = df[df[cluster_id] != 'single']
    clusters = clusters[clusters[date_col].notnull()]
    
    groups = clusters.groupby(clusters[cluster_id])
    
    return groups

# %%
def cluster_builder(df, cluster_id, case_id, date_col, color_col, inc_mean, inc_sd):
    '''
    Given a line listing with dates and basic information about cluster membership,
    this script will estimate who transmitted an infectious disease to whom based on case onset dates.

    df = pandas dataframe of line listing
    cluster_id = col that identifies cluster membership, which can be a basic string like "hospital cluster A"
    case_id = col with unique case identifier
    date_col = onset or report date column
    color_col = column that will be used to color nodes based on attribute, e.g. case severity or gender
    inc_mean = incubation period mean
    inc_sd = incubation period standard deviation

    retuns clusters (pandas dataframe) and mx (networkx object)
    '''
    clusters = _group_clusters(df, cluster_id, date_col)
    
    mmin = timedelta(inc_mean - (1 * inc_sd), 0)
    mmax = timedelta(inc_mean + (1 * inc_sd), 0)
    
    mx = []
    for key, group in clusters:
        #suspect this will be buggy with dif data sets, woudl like to improve
        row = [tmp[1:4] for tmp in group[[case_id, date_col, color_col]].sort('dates').itertuples()]
        mx.append(row)

    network = []
    for ix in range(0, len(mx)):
        for inx in range(0, len(mx[ix])):
            index_node = mx[ix][0][0]
            source_node = index_node
            case_id = mx[ix][inx][0]
            time = mx[ix][inx][1]
            color = mx[ix][inx][2]
            
            if len(mx[ix]) > 1:
               if mx[ix][inx][1] - mx[ix][inx-1][1] > mmin:
                    source_node = mx[ix][inx-1][0]
        
            result = (case_id, color, index_node, source_node, time)
            network.append(result)
            
    df_out = pd.DataFrame(network, columns=['case_id', 'color', 'index_node', 'source_node', 'time'])
    df_out.index = df_out.case_id
    
    
    
    return df_out

# %%
clusters = cluster_builder(dat, 'Cluster ID', 'Case #', 'dates', 'Health status', 7, 5)
clusters = cluster_builder(dat, 'Cluster ID', 'Case #', 'dates', 'Cluster ID', 7, 5)

# %%
clusters.head()
# Out:
#          case_id      color  index_node  source_node                time
# case_id
# 51            51  Cluster A          51           51 2013-05-31 00:00:00
# 52            52  Cluster A          51           51 2013-06-01 00:00:00
# 53            53  Cluster A          51           51 2013-06-01 00:00:00
# 114          114  Cluster E         114          114 2013-08-15 00:00:00
# 115          115  Cluster E         114          114 2013-08-21 00:00:00

# %%
clusters.to_pickle('../cluster_network.pkl')

# %%
def plot_cluster(df, clusters, cluster_id, date_col):
    """Broken. Date-handling patience gone.

    Should display a plot with time along x axis, cluster ID along y axis,
    and case ID plotted like a scatterplot accordingly.
    """
    grpnames = np.unique(df[cluster_id]).dropna().values
    
    fig, ax = plt.subplots(figsize=(8, 5))
    ax.xaxis_date()
    ax.set_aspect('auto')
    axprop =  ax.axis()
    
    plt.ylim(1, len(grpnames))
    plt.yticks(np.arange(len(grpnames)), grpnames)
    
    xtog = timedelta(((10*axprop[1]-axprop[0])/axprop[1]), 0, 0)
    
    for key, group in clusters.iteritems():
        if key == 'time':
            for date in group:
                x1 = [date, date+xtog]
                print x1

#         for i in range(len(grpnames)):
#                 print('key: {0}
#                 for grp in group:
#                     if key == grpnames[i]:
#                         y1 = np.array([i, i])
#                         y2 = y1+0.5
#                         plt.fill_between(x1, y1, y2, color=color, alpha=.3)
                            
#                         xspot= x1[0] + timedelta((x1[1] - x1[0]).days/2.0, 0, 0)
                            
#                         plt.text(xspot, y1[1]+.25, next(casenums), horizontalalignment='center', verticalalignment='center', fontsize=9)
    
                   
    fig.tight_layout()
    fig.autofmt_xdate()
    return fig, ax

# %%
grpnames = np.unique(dat['Cluster ID']).dropna().values

fig, ax = plt.subplots(figsize=(8, 5))
ax.xaxis_date()
ax.set_aspect('auto')
axprop =  ax.axis()

plt.ylim(1, len(grpnames))
plt.yticks(np.arange(len(grpnames)), grpnames)

xtog = timedelta(((10*axprop[1]-axprop[0])/axprop[1]), 0, 0)
x1 = [[t.to_datetime(), t.to_datetime()+xtog] for t in clusters['time']]

for i in range(len(grpnames)):
        print('key: {0}
        for grp in group:
            if key == grpnames[i]:
                y1 = np.array([i, i])
                y2 = y1+0.5
                plt.fill_between(x1, y1, y2, color=color, alpha=.3)
                    
                xspot= x1[0] + timedelta((x1[1] - x1[0]).days/2.0, 0, 0)
                    
                plt.text(xspot, y1[1]+.25, next(casenums), horizontalalignment='center', verticalalignment='center', fontsize=9)

# %%
groups = _group_clusters(dat, 'Cluster ID', 'dates')

# %%
groups[['Age']].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 67 entries, (Cluster A, Cluster A) to (hospital A, hospital A)
# Data columns (total 17 columns):
# Case #                      67  non-null values
# Approx onset date           29  non-null values
# Approx reporting date       39  non-null values
# Age                         64  non-null values
# Sex                         63  non-null values
# Probable infection place    65  non-null values
# Health status               66  non-null values
# Approx death date           15  non-null values
# Region                      38  non-null values
# HCW                         14  non-null values
# Reported comorbidities      19  non-null values
# Cluster ID                  67  non-null values
# Notes                       14  non-null values
#  Zoonotic                   60  non-null values
# onset_date                  29  non-null values
# report_date                 39  non-null values
# dates                       67  non-null values
# dtypes: float64(2), object(15)

# %%
clusters['time'], clusters['time']
# Out:
# case_id
# 51        2013-05-31 00:00:00
# 52        2013-06-01 00:00:00
# 53        2013-06-01 00:00:00
# 114       2013-08-15 00:00:00
# 115       2013-08-21 00:00:00
# 112       2013-09-01 00:00:00
# 163       2013-11-09 00:00:00
# 168       2013-12-06 00:00:00
# 33        2013-04-06 00:00:00
# 18        2013-04-14 00:00:00
# 29        2013-04-15 00:00:00
# 19        2013-04-17 00:00:00
# 20        2013-04-17 00:00:00
# 28        2013-04-19 00:00:00
# 21        2013-04-22 00:00:00
# ...
# 153       2013-10-15 00:00:00
# 167       2013-11-22 00:00:00
# 82        2013-07-12 00:00:00
# 85        2013-07-18 00:00:00
# 86        2013-07-18 00:00:00
# 87        2013-07-18 00:00:00
# 88        2013-07-18 00:00:00
# 101       2013-08-22 00:00:00
# 113       2013-08-23 00:00:00
# 121       2013-09-08 00:00:00
# 124       2013-09-08 00:00:00
# 133       2013-09-18 00:00:00
# 134       2013-09-18 00:00:00
# 1         2012-04-01 00:00:00
# 2         2012-04-01 00:00:00
# Name: time, Length: 96, dtype: datetime64[ns]

# %%
for key, value in clusters.iteritems():
    print key
# Out:
# case_id
# color
# index_node
# source_node
# time

# %%
fig, ax = plot_cluster(dat, clusters, 'Cluster ID', 'dates')
display(fig)
# Out:
# [Timestamp('2013-05-31 00:00:00', tz=None), Timestamp('2013-06-09 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-01 00:00:00', tz=None), Timestamp('2013-06-10 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-01 00:00:00', tz=None), Timestamp('2013-06-10 00:07:10.131935', tz=None)]
# [Timestamp('2013-08-15 00:00:00', tz=None), Timestamp('2013-08-24 00:07:10.131935', tz=None)]
# [Timestamp('2013-08-21 00:00:00', tz=None), Timestamp('2013-08-30 00:07:10.131935', tz=None)]
# [Timestamp('2013-09-01 00:00:00', tz=None), Timestamp('2013-09-10 00:07:10.131935', tz=None)]
# [Timestamp('2013-11-09 00:00:00', tz=None), Timestamp('2013-11-18 00:07:10.131935', tz=None)]
# [Timestamp('2013-12-06 00:00:00', tz=None), Timestamp('2013-12-15 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-06 00:00:00', tz=None), Timestamp('2013-04-15 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-14 00:00:00', tz=None), Timestamp('2013-04-23 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-15 00:00:00', tz=None), Timestamp('2013-04-24 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-17 00:00:00', tz=None), Timestamp('2013-04-26 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-17 00:00:00', tz=None), Timestamp('2013-04-26 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-19 00:00:00', tz=None), Timestamp('2013-04-28 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-22 00:00:00', tz=None), Timestamp('2013-05-01 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-22 00:00:00', tz=None), Timestamp('2013-05-01 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-22 00:00:00', tz=None), Timestamp('2013-05-01 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-22 00:00:00', tz=None), Timestamp('2013-05-01 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-23 00:00:00', tz=None), Timestamp('2013-05-02 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-24 00:00:00', tz=None), Timestamp('2013-05-03 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-25 00:00:00', tz=None), Timestamp('2013-05-04 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-26 00:00:00', tz=None), Timestamp('2013-05-05 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-28 00:00:00', tz=None), Timestamp('2013-05-07 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-29 00:00:00', tz=None), Timestamp('2013-05-08 00:07:10.131935', tz=None)]
# [Timestamp('2013-05-01 00:00:00', tz=None), Timestamp('2013-05-10 00:07:10.131935', tz=None)]
# [Timestamp('2013-05-07 00:00:00', tz=None), Timestamp('2013-05-16 00:07:10.131935', tz=None)]
# [Timestamp('2013-05-12 00:00:00', tz=None), Timestamp('2013-05-21 00:07:10.131935', tz=None)]
# [Timestamp('2013-05-17 00:00:00', tz=None), Timestamp('2013-05-26 00:07:10.131935', tz=None)]
# [Timestamp('2013-05-18 00:00:00', tz=None), Timestamp('2013-05-27 00:07:10.131935', tz=None)]
# [Timestamp('2013-05-19 00:00:00', tz=None), Timestamp('2013-05-28 00:07:10.131935', tz=None)]
# [Timestamp('2013-05-24 00:00:00', tz=None), Timestamp('2013-06-02 00:07:10.131935', tz=None)]
# [Timestamp('2013-05-29 00:00:00', tz=None), Timestamp('2013-06-07 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-04 00:00:00', tz=None), Timestamp('2013-06-13 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-11 00:00:00', tz=None), Timestamp('2013-06-20 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-11 00:00:00', tz=None), Timestamp('2013-06-20 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-17 00:00:00', tz=None), Timestamp('2013-06-26 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-21 00:00:00', tz=None), Timestamp('2013-06-30 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-22 00:00:00', tz=None), Timestamp('2013-07-01 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-23 00:00:00', tz=None), Timestamp('2013-07-02 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-23 00:00:00', tz=None), Timestamp('2013-07-02 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-23 00:00:00', tz=None), Timestamp('2013-07-02 00:07:10.131935', tz=None)]
# [Timestamp('2013-07-11 00:00:00', tz=None), Timestamp('2013-07-20 00:07:10.131935', tz=None)]
# [Timestamp('2012-10-01 00:00:00', tz=None), Timestamp('2012-10-10 00:07:10.131935', tz=None)]
# [Timestamp('2012-10-28 00:00:00', tz=None), Timestamp('2012-11-06 00:07:10.131935', tz=None)]
# [Timestamp('2012-11-05 00:00:00', tz=None), Timestamp('2012-11-14 00:07:10.131935', tz=None)]
# [Timestamp('2013-01-24 00:00:00', tz=None), Timestamp('2013-02-02 00:07:10.131935', tz=None)]
# [Timestamp('2013-02-06 00:00:00', tz=None), Timestamp('2013-02-15 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-20 00:00:00', tz=None), Timestamp('2013-04-29 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-20 00:00:00', tz=None), Timestamp('2013-04-29 00:07:10.131935', tz=None)]
# [Timestamp('2013-05-01 00:00:00', tz=None), Timestamp('2013-05-10 00:07:10.131935', tz=None)]
# [Timestamp('2013-08-08 00:00:00', tz=None), Timestamp('2013-08-17 00:07:10.131935', tz=None)]
# [Timestamp('2013-08-30 00:00:00', tz=None), Timestamp('2013-09-08 00:07:10.131935', tz=None)]
# [Timestamp('2013-08-30 00:00:00', tz=None), Timestamp('2013-09-08 00:07:10.131935', tz=None)]
# [Timestamp('2013-09-01 00:00:00', tz=None), Timestamp('2013-09-10 00:07:10.131935', tz=None)]
# [Timestamp('2013-09-01 00:00:00', tz=None), Timestamp('2013-09-10 00:07:10.131935', tz=None)]
# [Timestamp('2013-11-15 00:00:00', tz=None), Timestamp('2013-11-24 00:07:10.131935', tz=None)]
# [Timestamp('2013-11-28 00:00:00', tz=None), Timestamp('2013-12-07 00:07:10.131935', tz=None)]
# [Timestamp('2013-12-01 00:00:00', tz=None), Timestamp('2013-12-10 00:07:10.131935', tz=None)]
# [Timestamp('2013-02-24 00:00:00', tz=None), Timestamp('2013-03-05 00:07:10.131935', tz=None)]
# [Timestamp('2013-03-02 00:00:00', tz=None), Timestamp('2013-03-11 00:07:10.131935', tz=None)]
# [Timestamp('2013-04-27 00:00:00', tz=None), Timestamp('2013-05-06 00:07:10.131935', tz=None)]
# [Timestamp('2013-07-17 00:00:00', tz=None), Timestamp('2013-07-26 00:07:10.131935', tz=None)]
# [Timestamp('2013-07-17 00:00:00', tz=None), Timestamp('2013-07-26 00:07:10.131935', tz=None)]
# [Timestamp('2013-05-02 00:00:00', tz=None), Timestamp('2013-05-11 00:07:10.131935', tz=None)]
# [Timestamp('2013-05-08 00:00:00', tz=None), Timestamp('2013-05-17 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-22 00:00:00', tz=None), Timestamp('2013-07-01 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-22 00:00:00', tz=None), Timestamp('2013-07-01 00:07:10.131935', tz=None)]
# [Timestamp('2013-06-22 00:00:00', tz=None), Timestamp('2013-07-01 00:07:10.131935', tz=None)]
# [Timestamp('2013-09-11 00:00:00', tz=None), Timestamp('2013-09-20 00:07:10.131935', tz=None)]
# [Timestamp('2013-09-11 00:00:00', tz=None), Timestamp('2013-09-20 00:07:10.131935', tz=None)]
# [Timestamp('2013-09-11 00:00:00', tz=None), Timestamp('2013-09-20 00:07:10.131935', tz=None)]
# [Timestamp('2013-09-11 00:00:00', tz=None), Timestamp('2013-09-20 00:07:10.131935', tz=None)]
# [Timestamp('2013-10-19 00:00:00', tz=None), Timestamp('2013-10-28 00:07:10.131935', tz=None)]
# [Timestamp('2013-10-26 00:00:00', tz=None), Timestamp('2013-11-04 00:07:10.131935', tz=None)]
# [Timestamp('2013-10-26 00:00:00', tz=None), Timestamp('2013-11-04 00:07:10.131935', tz=None)]
# [Timestamp('2013-10-01 00:00:00', tz=None), Timestamp('2013-10-10 00:07:10.131935', tz=None)]
# [Timestamp('2013-10-01 00:00:00', tz=None), Timestamp('2013-10-10 00:07:10.131935', tz=None)]
# [Timestamp('2013-10-01 00:00:00', tz=None), Timestamp('2013-10-10 00:07:10.131935', tz=None)]
# [Timestamp('2013-12-13 00:00:00', tz=None), Timestamp('2013-12-22 00:07:10.131935', tz=None)]
# [Timestamp('2013-10-11 00:00:00', tz=None), Timestamp('2013-10-20 00:07:10.131935', tz=None)]
# [Timestamp('2013-10-27 00:00:00', tz=None), Timestamp('2013-11-05 00:07:10.131935', tz=None)]
# [Timestamp('2013-10-15 00:00:00', tz=None), Timestamp('2013-10-24 00:07:10.131935', tz=None)]
# [Timestamp('2013-11-22 00:00:00', tz=None), Timestamp('2013-12-01 00:07:10.131935', tz=None)]
# [Timestamp('2013-07-12 00:00:00', tz=None), Timestamp('2013-07-21 00:07:10.131935', tz=None)]
# [Timestamp('2013-07-18 00:00:00', tz=None), Timestamp('2013-07-27 00:07:10.131935', tz=None)]
# [Timestamp('2013-07-18 00:00:00', tz=None), Timestamp('2013-07-27 00:07:10.131935', tz=None)]
# [Timestamp('2013-07-18 00:00:00', tz=None), Timestamp('2013-07-27 00:07:10.131935', tz=None)]
# [Timestamp('2013-07-18 00:00:00', tz=None), Timestamp('2013-07-27 00:07:10.131935', tz=None)]
# [Timestamp('2013-08-22 00:00:00', tz=None), Timestamp('2013-08-31 00:07:10.131935', tz=None)]
# [Timestamp('2013-08-23 00:00:00', tz=None), Timestamp('2013-09-01 00:07:10.131935', tz=None)]
# [Timestamp('2013-09-08 00:00:00', tz=None), Timestamp('2013-09-17 00:07:10.131935', tz=None)]
# [Timestamp('2013-09-08 00:00:00', tz=None), Timestamp('2013-09-17 00:07:10.131935', tz=None)]
# [Timestamp('2013-09-18 00:00:00', tz=None), Timestamp('2013-09-27 00:07:10.131935', tz=None)]
# [Timestamp('2013-09-18 00:00:00', tz=None), Timestamp('2013-09-27 00:07:10.131935', tz=None)]
# [Timestamp('2012-04-01 00:00:00', tz=None), Timestamp('2012-04-10 00:07:10.131935', tz=None)]
# [Timestamp('2012-04-01 00:00:00', tz=None), Timestamp('2012-04-10 00:07:10.131935', tz=None)]

# %%
plt.close('all')
