# %% [markdown]
# # Basic transmission tree builder
#
# * Caitlin Rivers
#
# * Virginia Bioinformatics Institute at Virginia Tech
#
# * cmrivers@vbi.vt.edu
#
# -------
#
# Given a line listing with dates and basic information about cluster membership, this script will estimate who transmitted an infectious disease to whom based on case onset dates.
#
# Wish list for improvements:
#
# * Make algorithm that determines who infected whom more sophisticated.
#
# * Find a way to keep single cases (e.g. those not part of a cluster) in the data set so they can be plotted on the casetree.
#
# * Fix plot_cluster() function so it is functional.

# %%
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime, timedelta
import pandas as pd
from itertools import cycle

try:
    from mpltools import style, layout
    style.use('ggplot')
except:
    pass

# %%
def date_convert(x):
    """ Convert dates to datetime object
    """
    try:
        y = datetime.strptime(x, "%Y-%m-%d")
    except:
        y = np.nan
        
    return y

# %% [markdown]
# Data (from 2013 MERS outbreak) are available in cmrivers/epipy repo on Github.

# %%
dat = pd.read_csv("../Line list & epi stats - Line list.csv", parse_dates=True)
dat['Cluster ID'] = dat['Cluster ID'].replace(np.nan, 'single')
dat.index = dat['Case #']

# %%
dat
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 1.0 to 181.0
# Data columns (total 14 columns):
# Case #                      181  non-null values
# Approx onset date           80  non-null values
# Approx reporting date       103  non-null values
# Age                         172  non-null values
# Sex                         159  non-null values
# Probable infection place    180  non-null values
# Health status               178  non-null values
# Approx death date           42  non-null values
# Region                      130  non-null values
# HCW                         26  non-null values
# Reported comorbidities      88  non-null values
# Cluster ID                  182  non-null values
# Notes                       33  non-null values
#  Zoonotic                   154  non-null values
# dtypes: float64(2), object(12)

# %%
dat['onset_date'] = dat['Approx onset date'].map(date_convert)
dat['report_date'] = dat['Approx reporting date'].map(date_convert)
dat['dates'] = dat['onset_date'].combine_first(dat['report_date']) #combines onset and report date columns, with onset date preferential

# %%
def _group_clusters(df, cluster_id, date_col):
    ''' Use pandas to group clusters by basic cluster membership information
    df = pandas dataframe
    cluster_id = column that identifies cluster membership, which can be a basic string like "hospital cluster A"
    date_col = onset or report date column
    '''
    clusters = df[df[cluster_id] != 'single']
    clusters = clusters[clusters[date_col].notnull()]
    
    groups = clusters.groupby(clusters[cluster_id])
    
    return groups

# %%
def cluster_builder(df, cluster_id, case_id, date_col, color_col, inf_mean, inf_sd):
    '''
    Given a line listing with dates and basic information about cluster membership,
    this script will estimate who transmitted an infectious disease to whom based on case onset dates.

    df = pandas dataframe of line listing
    cluster_id = col that identifies cluster membership, which can be a basic string like "hospital cluster A"
    case_id = col with unique case identifier
    date_col = onset or report date column
    color_col = column that will be used to color nodes based on attribute, e.g. case severity or gender
    inf_mean = infectious period mean
    inf_sd = infectious period standard deviation

    returns networkx object
    '''
    clusters = _group_clusters(df, cluster_id, date_col)
    
    mmin = timedelta(inf_mean - (1 * inf_sd), 0)
    mmax = timedelta(inf_mean + (1 * inf_sd), 0)
    
    mx = []
    for key, group in clusters:
        #suspect this will be buggy with dif data sets, woudl like to improve
        row = [tmp[1:4] for tmp in group[[case_id, date_col, color_col]].sort('dates').itertuples()]
        mx.append(row)

    network = []
    for ix in range(0, len(mx)):
        for inx in range(0, len(mx[ix])):
            index_node = mx[ix][0][0]
            source_node = index_node
            case_id = mx[ix][inx][0]
            time = mx[ix][inx][1]
            color = mx[ix][inx][2]
            
            if len(mx[ix]) > 1:
                dur = mx[ix][inx][1] - mx[ix][inx-1][1]
                if (dur > mmin):
                    source_node = mx[ix][inx-1][0] 
                
        
            result = (case_id, color, index_node, source_node, time)
            network.append(result)
            
    df_out = pd.DataFrame(network, columns=['case_id', 'color', 'index_node', 'source_node', 'time'])
    df_out.index = df_out.case_id
    
    
    
    return df_out

# %%
def cluster_builder(df, cluster_id, case_id, date_col, color_col, inf_mean, inf_sd):
    '''
    Given a line listing with dates and basic information about cluster membership,
    this script will estimate who transmitted an infectious disease to whom based on case onset dates.

    df = pandas dataframe of line listing
    cluster_id = col that identifies cluster membership, which can be a basic string like "hospital cluster A"
    case_id = col with unique case identifier
    date_col = onset or report date column
    color_col = column that will be used to color nodes based on attribute, e.g. case severity or gender
    inf_mean = infectious period mean
    inf_sd = infectious period standard deviation

    returns networkx object
    '''
    df = df[df[date_col].isnull() == False]
    #clusters = _group_clusters(df, cluster_id, date_col)
    
    mmin = timedelta(inf_mean - (1 * inf_sd), 0)
    mmax = timedelta(inf_mean + (1 * inf_sd), 0)
    
    mx = []
    
    clusters = np.unique(df[cluster_id])
    
    for group in clusters:
        block = df[df[cluster_id] == group].sort(date_col)
        for row in block.iteritems():
            print row

# %%
clusters = cluster_builder(dat, 'Cluster ID', 'Case #', 'dates', 'Health status', 5, 2)
# Out:
# ('Case #', Case #
# 51        51
# 52        52
# 53        53
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 51        NaN
# 52        NaN
# 53        NaN
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 51        2013-05-31
# 52        2013-06-01
# 53        2013-06-01
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 51        45
# 52         2
# 53        40
# Name: Age, dtype: float64)
# ('Sex', Case #
# 51        M
# 52        F
# 53        F
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 51        Italy
# 52        Italy
# 53        Italy
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 51        Alive
# 52        Alive
# 53        Alive
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 51        NaN
# 52        NaN
# 53        NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 51        NaN
# 52        NaN
# 53        NaN
# Name: Region, dtype: object)
# ('HCW', Case #
# 51        NaN
# 52        NaN
# 53        NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 51        NaN
# 52        NaN
# 53        NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 51        Cluster A
# 52        Cluster A
# 53        Cluster A
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 51        Travel hx to Jordan
# 52                        NaN
# 53                        NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 51        H
# 52        L
# 53        L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 51        NaN
# 52        NaN
# 53        NaN
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 51        2013-05-31 00:00:00
# 52        2013-06-01 00:00:00
# 53        2013-06-01 00:00:00
# Name: report_date, dtype: object)
# ('dates', Case #
# 51        2013-05-31 00:00:00
# 52        2013-06-01 00:00:00
# 53        2013-06-01 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 114       114
# 115       115
# 112       112
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 114       2013-08-15
# 115       2013-08-21
# 112       2013-09-01
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 114       NaN
# 115       NaN
# 112       NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 114       41
# 115       79
# 112       30
# Name: Age, dtype: float64)
# ('Sex', Case #
# 114       F
# 115       F
# 112       M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 114       Saudi Arabia
# 115       Saudi Arabia
# 112       Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 114           Dead
# 115           Dead
# 112       Critical
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 114       2013-08-31
# 115       2013-09-02
# 112              NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 114               Riyadh
# 115       Hafar Al-batin
# 112               Riyadh
# Name: Region, dtype: object)
# ('HCW', Case #
# 114         Y
# 115       NaN
# 112         Y
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 114       NaN
# 115         Y
# 112       NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 114       Cluster E
# 115       Cluster E
# 112       Cluster E
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 114       NaN
# 115       NaN
# 112       NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 114       L
# 115       L
# 112       H
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 114       2013-08-15 00:00:00
# 115       2013-08-21 00:00:00
# 112       2013-09-01 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 114       NaN
# 115       NaN
# 112       NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 114       2013-08-15 00:00:00
# 115       2013-08-21 00:00:00
# 112       2013-09-01 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 163       163
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 163       2013-11-09
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 163       NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 163       37
# Name: Age, dtype: float64)
# ('Sex', Case #
# 163       M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 163       Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 163       Dead
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 163       2013-11-18
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 163       Riyadh
# Name: Region, dtype: object)
# ('HCW', Case #
# 163       NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 163       NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 163       Dec
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 163       NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 163       NaN
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 163       2013-11-09 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 163       NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 163       2013-11-09 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 168       168
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 168       NaN
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 168       2013-12-06
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 168       26
# Name: Age, dtype: float64)
# ('Sex', Case #
# 168       NaN
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 168       Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 168       Asymptomatic
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 168       NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 168       Riyadh
# Name: Region, dtype: object)
# ('HCW', Case #
# 168       Y
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 168       NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 168       Deec
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 168       NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 168       NaN
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 168       NaN
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 168       2013-12-06 00:00:00
# Name: report_date, dtype: object)
# ('dates', Case #
# 168       2013-12-06 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 33        33
# 18        18
# 29        29
# 19        19
# 20        20
# 28        28
# 23        23
# 21        21
# 22        22
# 24        24
# 31        31
# 36        36
# 35        35
# 37        37
# 41        41
# 32        32
# 30        30
# 38        38
# 45        45
# 46        46
# 49        49
# 48        48
# 47        47
# 54        54
# 55        55
# 56        56
# 57        57
# 62        62
# 70        70
# 65        65
# 75        75
# 76        76
# 77        77
# 90        90
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 33        2013-04-06
# 18        2013-04-14
# 29        2013-04-15
# 19        2013-04-17
# 20        2013-04-17
# 28        2013-04-19
# 23        2013-04-22
# 21        2013-04-22
# 22        2013-04-22
# 24        2013-04-22
# 31        2013-04-23
# 36        2013-04-24
# 35        2013-04-25
# 37        2013-04-26
# 41        2013-04-28
# 32        2013-04-29
# 30        2013-05-01
# 38        2013-05-07
# 45        2013-05-12
# 46        2013-05-17
# 49        2013-05-18
# 48        2013-05-19
# 47        2013-05-24
# 54        2013-05-29
# 55               NaN
# 56               NaN
# 57               NaN
# 62               NaN
# 70               NaN
# 65               NaN
# 75               NaN
# 76               NaN
# 77               NaN
# 90        2013-07-11
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 33               NaN
# 18               NaN
# 29               NaN
# 19               NaN
# 20               NaN
# 28               NaN
# 23               NaN
# 21               NaN
# 22               NaN
# 24               NaN
# 31               NaN
# 36               NaN
# 35               NaN
# 37               NaN
# 41               NaN
# 32               NaN
# 30               NaN
# 38               NaN
# 45               NaN
# 46               NaN
# 49               NaN
# 48               NaN
# 47               NaN
# 54               NaN
# 55        2013-06-04
# 56        2013-06-11
# 57        2013-06-11
# 62        2013-06-17
# 70        2013-06-21
# 65        2013-06-22
# 75        2013-06-23
# 76        2013-06-23
# 77        2013-06-23
# 90               NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 33        58
# 18        59
# 29        71
# 19        24
# 20        87
# 28        62
# 23        56
# 21        58
# 22        94
# 24        56
# 31        65
# 36        48
# 35        69
# 37        81
# 41        81
# 32        48
# 30        58
# 38        56
# 45        56
# 46        85
# 49        73
# 48        77
# 47        76
# 54        14
# 55        83
# 56        63
# 57        75
# 62        42
# 70        32
# 65        43
# 75       NaN
# 76       NaN
# 77        50
# 90        59
# Name: Age, dtype: float64)
# ('Sex', Case #
# 33        M
# 18        M
# 29        M
# 19        M
# 20        M
# 28        F
# 23        M
# 21        M
# 22        M
# 24        M
# 31        M
# 36        M
# 35        F
# 37        M
# 41        F
# 32        M
# 30        F
# 38        M
# 45        M
# 46        F
# 49        M
# 48        M
# 47        F
# 54        F
# 55        M
# 56        F
# 57        M
# 62        M
# 70        M
# 65        F
# 75        F
# 76        F
# 77        F
# 90        F
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 33        Saudi Arabia
# 18        Saudi Arabia
# 29        Saudi Arabia
# 19        Saudi Arabia
# 20        Saudi Arabia
# 28        Saudi Arabia
# 23        Saudi Arabia
# 21        Saudi Arabia
# 22        Saudi Arabia
# 24        Saudi Arabia
# 31              France
# 36        Saudi Arabia
# 35        Saudi Arabia
# 37        Saudi Arabia
# 41        Saudi Arabia
# 32        Saudi Arabia
# 30        Saudi Arabia
# 38        Saudi Arabia
# 45        Saudi Arabia
# 46        Saudi Arabia
# 49        Saudi Arabia
# 48        Saudi Arabia
# 47        Saudi Arabia
# 54        Saudi Arabia
# 55        Saudi Arabia
# 56        Saudi Arabia
# 57        Saudi Arabia
# 62        Saudi Arabia
# 70        Saudi Arabia
# 65        Saudi Arabia
# 75        Saudi Arabia
# 76        Saudi Arabia
# 77        Saudi Arabia
# 90        Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 33           Recovered
# 18                Dead
# 29                Dead
# 19                Dead
# 20                Dead
# 28                Dead
# 23                Dead
# 21            Critical
# 22                Dead
# 24                Dead
# 31                Dead
# 36            Critical
# 35                Dead
# 37            Critical
# 41                Dead
# 32               Alive
# 30            Critical
# 38               Alive
# 45                Dead
# 46            Critical
# 49                Dead
# 48                Dead
# 47           Recovered
# 54               Alive
# 55                Dead
# 56               Alive
# 57                Dead
# 62               Alive
# 70                Dead
# 65           Recovered
# 75        Asymptomatic
# 76        Asymptomatic
# 77               Alive
# 90            Critical
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 33               NaN
# 18        2013-03-19
# 29        2013-05-03
# 19        2013-05-31
# 20        2013-05-28
# 28        2013-05-03
# 23        2013-04-30
# 21               NaN
# 22        2013-04-26
# 24        2013-04-29
# 31               NaN
# 36               NaN
# 35               NaN
# 37               NaN
# 41               NaN
# 32               NaN
# 30               NaN
# 38               NaN
# 45        2013-05-20
# 46               NaN
# 49        2013-05-26
# 48        2013-05-26
# 47               NaN
# 54               NaN
# 55        2013-05-06
# 56               NaN
# 57        2013-05-05
# 62               NaN
# 70        2013-06-23
# 65               NaN
# 75               NaN
# 76               NaN
# 77               NaN
# 90               NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 33        Eastern
# 18        Eastern
# 29        Eastern
# 19        Eastern
# 20        Eastern
# 28        Eastern
# 23        Eastern
# 21        Eastern
# 22        Eastern
# 24        Eastern
# 31        Eastern
# 36        Eastern
# 35        Eastern
# 37        Eastern
# 41        Eastern
# 32        Eastern
# 30        Eastern
# 38        Eastern
# 45        Eastern
# 46        Eastern
# 49        Eastern
# 48        Eastern
# 47        Eastern
# 54        Eastern
# 55        Eastern
# 56        Eastern
# 57        Eastern
# 62        Eastern
# 70        Eastern
# 65        Eastern
# 75        Eastern
# 76        Eastern
# 77        Eastern
# 90        Eastern
# Name: Region, dtype: object)
# ('HCW', Case #
# 33        NaN
# 18        NaN
# 29        NaN
# 19        NaN
# 20        NaN
# 28        NaN
# 23        NaN
# 21        NaN
# 22        NaN
# 24        NaN
# 31        NaN
# 36        NaN
# 35        NaN
# 37        NaN
# 41        NaN
# 32        NaN
# 30        NaN
# 38        NaN
# 45        NaN
# 46        NaN
# 49        NaN
# 48        NaN
# 47        NaN
# 54        NaN
# 55        NaN
# 56        NaN
# 57        NaN
# 62        NaN
# 70        NaN
# 65        NaN
# 75        NaN
# 76        NaN
# 77        NaN
# 90        NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 33          Y
# 18          Y
# 29          Y
# 19          Y
# 20          Y
# 28          Y
# 23          Y
# 21          Y
# 22          Y
# 24          Y
# 31        NaN
# 36          Y
# 35          Y
# 37          Y
# 41          Y
# 32          Y
# 30          Y
# 38          Y
# 45          Y
# 46          Y
# 49          Y
# 48          Y
# 47          Y
# 54          Y
# 55          Y
# 56          Y
# 57          Y
# 62          Y
# 70          Y
# 65        NaN
# 75        NaN
# 76        NaN
# 77        NaN
# 90        NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 33        Eastern cluster
# 18        Eastern cluster
# 29        Eastern cluster
# 19        Eastern cluster
# 20        Eastern cluster
# 28        Eastern cluster
# 23        Eastern cluster
# 21        Eastern cluster
# 22        Eastern cluster
# 24        Eastern cluster
# 31        Eastern cluster
# 36        Eastern cluster
# 35        Eastern cluster
# 37        Eastern cluster
# 41        Eastern cluster
# 32        Eastern cluster
# 30        Eastern cluster
# 38        Eastern cluster
# 45        Eastern cluster
# 46        Eastern cluster
# 49        Eastern cluster
# 48        Eastern cluster
# 47        Eastern cluster
# 54        Eastern cluster
# 55        Eastern cluster
# 56        Eastern cluster
# 57        Eastern cluster
# 62        Eastern cluster
# 70        Eastern cluster
# 65        Eastern cluster
# 75        Eastern cluster
# 76        Eastern cluster
# 77        Eastern cluster
# 90        Eastern cluster
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 33                                                    NaN
# 18                                                    NaN
# 29                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 28                                                    NaN
# 23                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 24                                                    NaN
# 31                                                    NaN
# 36                                                    NaN
# 35                                                    NaN
# 37                                          Possibly dead
# 41                                                    NaN
# 32                                                    NaN
# 30                                                    NaN
# 38                                                    NaN
# 45                                                    NaN
# 46                                                    NaN
# 49                                                    NaN
# 48                                                    NaN
# 47                                                    NaN
# 54                                                    NaN
# 55                                                    NaN
# 56                                                    NaN
# 57                                                    NaN
# 62                                                    NaN
# 70                                                    NaN
# 65                                                    NaN
# 75                                                    NaN
# 76                                                    NaN
# 77                                                    NaN
# 90        No known exposure to animals or infected humans
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 33        L
# 18        H
# 29        L
# 19        L
# 20        L
# 28        L
# 23        L
# 21        L
# 22        L
# 24        L
# 31        L
# 36        L
# 35        L
# 37        L
# 41        L
# 32        L
# 30        L
# 38        L
# 45        L
# 46        L
# 49        L
# 48        L
# 47        L
# 54        L
# 55        L
# 56        L
# 57        L
# 62        L
# 70        L
# 65        H
# 75        L
# 76        L
# 77        L
# 90        H
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 33        2013-04-06 00:00:00
# 18        2013-04-14 00:00:00
# 29        2013-04-15 00:00:00
# 19        2013-04-17 00:00:00
# 20        2013-04-17 00:00:00
# 28        2013-04-19 00:00:00
# 23        2013-04-22 00:00:00
# 21        2013-04-22 00:00:00
# 22        2013-04-22 00:00:00
# 24        2013-04-22 00:00:00
# 31        2013-04-23 00:00:00
# 36        2013-04-24 00:00:00
# 35        2013-04-25 00:00:00
# 37        2013-04-26 00:00:00
# 41        2013-04-28 00:00:00
# 32        2013-04-29 00:00:00
# 30        2013-05-01 00:00:00
# 38        2013-05-07 00:00:00
# 45        2013-05-12 00:00:00
# 46        2013-05-17 00:00:00
# 49        2013-05-18 00:00:00
# 48        2013-05-19 00:00:00
# 47        2013-05-24 00:00:00
# 54        2013-05-29 00:00:00
# 55                        NaN
# 56                        NaN
# 57                        NaN
# 62                        NaN
# 70                        NaN
# 65                        NaN
# 75                        NaN
# 76                        NaN
# 77                        NaN
# 90        2013-07-11 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 33                        NaN
# 18                        NaN
# 29                        NaN
# 19                        NaN
# 20                        NaN
# 28                        NaN
# 23                        NaN
# 21                        NaN
# 22                        NaN
# 24                        NaN
# 31                        NaN
# 36                        NaN
# 35                        NaN
# 37                        NaN
# 41                        NaN
# 32                        NaN
# 30                        NaN
# 38                        NaN
# 45                        NaN
# 46                        NaN
# 49                        NaN
# 48                        NaN
# 47                        NaN
# 54                        NaN
# 55        2013-06-04 00:00:00
# 56        2013-06-11 00:00:00
# 57        2013-06-11 00:00:00
# 62        2013-06-17 00:00:00
# 70        2013-06-21 00:00:00
# 65        2013-06-22 00:00:00
# 75        2013-06-23 00:00:00
# 76        2013-06-23 00:00:00
# 77        2013-06-23 00:00:00
# 90                        NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 33        2013-04-06 00:00:00
# 18        2013-04-14 00:00:00
# 29        2013-04-15 00:00:00
# 19        2013-04-17 00:00:00
# 20        2013-04-17 00:00:00
# 28        2013-04-19 00:00:00
# 23        2013-04-22 00:00:00
# 21        2013-04-22 00:00:00
# 22        2013-04-22 00:00:00
# 24        2013-04-22 00:00:00
# 31        2013-04-23 00:00:00
# 36        2013-04-24 00:00:00
# 35        2013-04-25 00:00:00
# 37        2013-04-26 00:00:00
# 41        2013-04-28 00:00:00
# 32        2013-04-29 00:00:00
# 30        2013-05-01 00:00:00
# 38        2013-05-07 00:00:00
# 45        2013-05-12 00:00:00
# 46        2013-05-17 00:00:00
# 49        2013-05-18 00:00:00
# 48        2013-05-19 00:00:00
# 47        2013-05-24 00:00:00
# 54        2013-05-29 00:00:00
# 55        2013-06-04 00:00:00
# 56        2013-06-11 00:00:00
# 57        2013-06-11 00:00:00
# 62        2013-06-17 00:00:00
# 70        2013-06-21 00:00:00
# 65        2013-06-22 00:00:00
# 75        2013-06-23 00:00:00
# 76        2013-06-23 00:00:00
# 77        2013-06-23 00:00:00
# 90        2013-07-11 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 9         9
# 8         8
# 7         7
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 9         2012-10-01
# 8         2012-10-28
# 7         2012-11-05
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 9         NaN
# 8         NaN
# 7         NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 9        NaN
# 8         39
# 7         31
# Name: Age, dtype: float64)
# ('Sex', Case #
# 9         M
# 8         M
# 7         M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 9         Saudi Arabia
# 8         Saudi Arabia
# 7         Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 9          Dead
# 8          Dead
# 7         Alive
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 9         NaN
# 8         NaN
# 7         NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 9            NaN
# 8            NaN
# 7         Riyadh
# Name: Region, dtype: object)
# ('HCW', Case #
# 9         NaN
# 8         NaN
# 7         NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 9         NaN
# 8         NaN
# 7         NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 9         Family A
# 8         Family A
# 7         Family A
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 9         NaN
# 8         NaN
# 7         NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 9         L
# 8         L
# 7         H
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 9         2012-10-01 00:00:00
# 8         2012-10-28 00:00:00
# 7         2012-11-05 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 9         NaN
# 8         NaN
# 7         NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 9         2012-10-01 00:00:00
# 8         2012-10-28 00:00:00
# 7         2012-11-05 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 10        10
# 11        11
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 10        2013-01-24
# 11        2013-02-06
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 10        NaN
# 11        NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 10        60
# 11       NaN
# Name: Age, dtype: float64)
# ('Sex', Case #
# 10        M
# 11        M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 10          Saudi Arabia
# 11        United Kingdom
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 10        Dead
# 11        Dead
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 10        2013-03-19
# 11        2013-02-17
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 10        NaN
# 11        NaN
# Name: Region, dtype: object)
# ('HCW', Case #
# 10        NaN
# 11        NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 10        NaN
# 11        NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 10        Family B
# 11        Family B
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 10        NaN
# 11        NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 10        H
# 11        L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 10        2013-01-24 00:00:00
# 11        2013-02-06 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 10        NaN
# 11        NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 10        2013-01-24 00:00:00
# 11        2013-02-06 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 42         42
# 43         43
# 116       116
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 42               NaN
# 43               NaN
# 116       2013-05-01
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 42        2013-04-20
# 43        2013-04-20
# 116              NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 42        35
# 43        34
# 116       66
# Name: Age, dtype: float64)
# ('Sex', Case #
# 42        F
# 43        M
# 116       M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 42        Saudi Arabia
# 43        Saudi Arabia
# 116            Tunisia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 42        Mild
# 43        Mild
# 116       Dead
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 42               NaN
# 43               NaN
# 116       2013-05-10
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 42        NaN
# 43        NaN
# 116       NaN
# Name: Region, dtype: object)
# ('HCW', Case #
# 42        NaN
# 43        NaN
# 116       NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 42        NaN
# 43        NaN
# 116       NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 42        Family C
# 43        Family C
# 116       Family C
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 42        Their 66yo father was index case, can't find h...
# 43        Their 66yo father was index case, can't find h...
# 116                              Travel hx to Qatar and KSA
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 42        L
# 43        L
# 116       L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 42                        NaN
# 43                        NaN
# 116       2013-05-01 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 42        2013-04-20 00:00:00
# 43        2013-04-20 00:00:00
# 116                       NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 42        2013-04-20 00:00:00
# 43        2013-04-20 00:00:00
# 116       2013-05-01 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 106       106
# 107       107
# 108       108
# 109       109
# 110       110
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 106       2013-08-08
# 107              NaN
# 108              NaN
# 109              NaN
# 110              NaN
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 106              NaN
# 107       2013-08-30
# 108       2013-08-30
# 109       2013-09-01
# 110       2013-09-01
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 106       38
# 107       16
# 108        7
# 109       26
# 110       19
# Name: Age, dtype: float64)
# ('Sex', Case #
# 106         M
# 107         M
# 108         F
# 109       NaN
# 110       NaN
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 106       Saudi Arabia
# 107       Saudi Arabia
# 108       Saudi Arabia
# 109                NaN
# 110                NaN
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 106               Dead
# 107       Asymptomatic
# 108       Asymptomatic
# 109          Recovered
# 110          Recovered
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 106       2013-08-17
# 107              NaN
# 108              NaN
# 109              NaN
# 110              NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 106       Hafar Al-batin
# 107       Hafar Al-batin
# 108       Hafar Al-batin
# 109       Hafar Al-batin
# 110       Hafar Al-batin
# Name: Region, dtype: object)
# ('HCW', Case #
# 106       NaN
# 107       NaN
# 108       NaN
# 109       NaN
# 110       NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 106         Y
# 107       NaN
# 108       NaN
# 109       NaN
# 110       NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 106       Family D
# 107       Family D
# 108       Family D
# 109       Family D
# 110       Family D
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 106       NaN
# 107       NaN
# 108       NaN
# 109       NaN
# 110       NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 106       H
# 107       L
# 108       L
# 109       L
# 110       L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 106       2013-08-08 00:00:00
# 107                       NaN
# 108                       NaN
# 109                       NaN
# 110                       NaN
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 106                       NaN
# 107       2013-08-30 00:00:00
# 108       2013-08-30 00:00:00
# 109       2013-09-01 00:00:00
# 110       2013-09-01 00:00:00
# Name: report_date, dtype: object)
# ('dates', Case #
# 106       2013-08-08 00:00:00
# 107       2013-08-30 00:00:00
# 108       2013-08-30 00:00:00
# 109       2013-09-01 00:00:00
# 110       2013-09-01 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 164       164
# 165       165
# 166       166
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 164       2013-11-15
# 165              NaN
# 166              NaN
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 164       2013-11-15
# 165       2013-11-28
# 166       2013-12-01
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 164       38
# 165       32
# 166        8
# Name: Age, dtype: float64)
# ('Sex', Case #
# 164       M
# 165       F
# 166       M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 164       UAE
# 165       UAE
# 166       UAE
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 164       Critical
# 165           Dead
# 166           Mild
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 164              NaN
# 165       2013-12-02
# 166              NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 164       Abu Dhabi
# 165             NaN
# 166             NaN
# Name: Region, dtype: object)
# ('HCW', Case #
# 164       NaN
# 165       NaN
# 166       NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 164       NaN
# 165       NaN
# 166       NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 164       FamilyPregnant
# 165       FamilyPregnant
# 166       FamilyPregnant
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 164       NaN
# 165       NaN
# 166       NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 164       NaN
# 165       NaN
# 166       NaN
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 164       2013-11-15 00:00:00
# 165                       NaN
# 166                       NaN
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 164       2013-11-15 00:00:00
# 165       2013-11-28 00:00:00
# 166       2013-12-01 00:00:00
# Name: report_date, dtype: object)
# ('dates', Case #
# 164       2013-11-15 00:00:00
# 165       2013-11-28 00:00:00
# 166       2013-12-01 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 15        15
# 16        16
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 15        2013-02-24
# 16        2013-03-02
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 15        NaN
# 16        NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 15        39
# 16        40
# Name: Age, dtype: float64)
# ('Sex', Case #
# 15        M
# 16        M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 15        Saudi Arabia
# 16        Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 15        Dead
# 16        Mild
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 15        2013-03-02
# 16               NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 15        Riyadh
# 16        Riyadh
# Name: Region, dtype: object)
# ('HCW', Case #
# 15        NaN
# 16        NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 15        NaN
# 16        NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 15        Group 2
# 16        Group 2
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 15        NaN
# 16        NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 15        H
# 16        L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 15        2013-02-24 00:00:00
# 16        2013-03-02 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 15        NaN
# 16        NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 15        2013-02-24 00:00:00
# 16        2013-03-02 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 34        34
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 34        2013-04-27
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 34        NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 34        50
# Name: Age, dtype: float64)
# ('Sex', Case #
# 34        M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 34        France
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 34        NaN
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 34        NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 34        NaN
# Name: Region, dtype: object)
# ('HCW', Case #
# 34        NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 34        Y
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 34        Group 6
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 34        Hospital roommate of case
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 34        L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 34        2013-04-27 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 34        NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 34        2013-04-27 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 83        83
# 84        84
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 83        NaN
# 84        NaN
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 83        2013-07-17
# 84        2013-07-17
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 83        26
# 84        42
# Name: Age, dtype: float64)
# ('Sex', Case #
# 83        M
# 84        F
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 83        Saudi Arabia
# 84        Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 83        Mild
# 84        Mild
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 83        NaN
# 84        NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 83        Asir
# 84        Asir
# Name: Region, dtype: object)
# ('HCW', Case #
# 83        NaN
# 84          Y
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 83        NaN
# 84        NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 83        Group A
# 84        Group A
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 83          Contact w/ previous  case
# 84        Probably healthcare cluster
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 83        H
# 84        L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 83        NaN
# 84        NaN
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 83        2013-07-17 00:00:00
# 84        2013-07-17 00:00:00
# Name: report_date, dtype: object)
# ('dates', Case #
# 83        2013-07-17 00:00:00
# 84        2013-07-17 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 39        39
# 40        40
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 39        2013-05-02
# 40        2013-05-08
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 39        NaN
# 40        NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 39        45
# 40        43
# Name: Age, dtype: float64)
# ('Sex', Case #
# 39        M
# 40        F
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 39        Saudi Arabia
# 40        Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 39        Critical
# 40           Alive
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 39        NaN
# 40        NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 39        NaN
# 40        NaN
# Name: Region, dtype: object)
# ('HCW', Case #
# 39        Y
# 40        Y
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 39        NaN
# 40        NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 39        Hospital B
# 40        Hospital B
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 39        NaN
# 40        NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 39        H
# 40        L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 39        2013-05-02 00:00:00
# 40        2013-05-08 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 39        NaN
# 40        NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 39        2013-05-02 00:00:00
# 40        2013-05-08 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 66        66
# 67        67
# 68        68
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 66        NaN
# 67        NaN
# 68        NaN
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 66        2013-06-22
# 67        2013-06-22
# 68        2013-06-22
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 66        29
# 67        39
# 68        45
# Name: Age, dtype: float64)
# ('Sex', Case #
# 66        F
# 67        F
# 68        F
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 66        Saudi Arabia
# 67        Saudi Arabia
# 68        Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 66        Asymptomatic
# 67        Asymptomatic
# 68               Alive
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 66        NaN
# 67        NaN
# 68        NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 66        Taif
# 67        Taif
# 68        Taif
# Name: Region, dtype: object)
# ('HCW', Case #
# 66        Y
# 67        Y
# 68        Y
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 66        NaN
# 67        NaN
# 68        NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 66        Hospital C
# 67        Hospital C
# 68        Hospital C
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 66        Two of the three cases announced on 6/22 are a...
# 67        Two of the three cases announced on 6/22 are a...
# 68        Two of the three cases announced on 6/22 are a...
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 66        H
# 67        L
# 68        L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 66        NaN
# 67        NaN
# 68        NaN
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 66        2013-06-22 00:00:00
# 67        2013-06-22 00:00:00
# 68        2013-06-22 00:00:00
# Name: report_date, dtype: object)
# ('dates', Case #
# 66        2013-06-22 00:00:00
# 67        2013-06-22 00:00:00
# 68        2013-06-22 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 129       129
# 130       130
# 131       131
# 132       132
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 129       NaN
# 130       NaN
# 131       NaN
# 132       NaN
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 129       2013-09-11
# 130       2013-09-11
# 131       2013-09-11
# 132       2013-09-11
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 129       51
# 130       47
# 131       39
# 132       38
# Name: Age, dtype: float64)
# ('Sex', Case #
# 129       F
# 130       F
# 131       F
# 132       M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 129       Saudi Arabia
# 130       Saudi Arabia
# 131       Saudi Arabia
# 132       Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 129       Alive
# 130        Mild
# 131        Mild
# 132       Alive
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 129       NaN
# 130       NaN
# 131       NaN
# 132       NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 129       NaN
# 130       NaN
# 131       NaN
# 132       NaN
# Name: Region, dtype: object)
# ('HCW', Case #
# 129       NaN
# 130         Y
# 131         Y
# 132         Y
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 129       NaN
# 130       NaN
# 131       NaN
# 132       NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 129       Hospital6
# 130       Hospital6
# 131       Hospital6
# 132       Hospital6
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 129       NaN
# 130       NaN
# 131       NaN
# 132       NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 129       L
# 130       L
# 131       L
# 132       L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 129       NaN
# 130       NaN
# 131       NaN
# 132       NaN
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 129       2013-09-11 00:00:00
# 130       2013-09-11 00:00:00
# 131       2013-09-11 00:00:00
# 132       2013-09-11 00:00:00
# Name: report_date, dtype: object)
# ('dates', Case #
# 129       2013-09-11 00:00:00
# 130       2013-09-11 00:00:00
# 131       2013-09-11 00:00:00
# 132       2013-09-11 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 146       146
# 147       147
# 152       152
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 146              NaN
# 147              NaN
# 152       2013-10-26
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 146       2013-10-19
# 147       2013-10-26
# 152              NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 146       54
# 147       83
# 152       56
# Name: Age, dtype: float64)
# ('Sex', Case #
# 146       NaN
# 147         F
# 152         F
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 146       Saudi Arabia
# 147       Saudi Arabia
# 152       Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 146       Dead
# 147       Dead
# 152       Dead
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 146       2012-10-22
# 147              NaN
# 152       2013-10-30
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 146        Jubail
# 147       Eastern
# 152       Eastern
# Name: Region, dtype: object)
# ('HCW', Case #
# 146       NaN
# 147       NaN
# 152       NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 146       Y
# 147       Y
# 152       Y
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 146       Jubail
# 147       Jubail
# 152       Jubail
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 146       NaN
# 147       NaN
# 152       NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 146       H
# 147       L
# 152       L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 146                       NaN
# 147                       NaN
# 152       2013-10-26 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 146       2013-10-19 00:00:00
# 147       2013-10-26 00:00:00
# 152                       NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 146       2013-10-19 00:00:00
# 147       2013-10-26 00:00:00
# 152       2013-10-26 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 139       139
# 140       140
# 141       141
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 139       NaN
# 140       NaN
# 141       NaN
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 139       2013-10-01
# 140       2013-10-01
# 141       2013-10-01
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 139       79
# 140       14
# 141       45
# Name: Age, dtype: float64)
# ('Sex', Case #
# 139       M
# 140       M
# 141       M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 139       Saudi Arabia
# 140       Saudi Arabia
# 141       Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 139          Alive
# 140          Alive
# 141       Critical
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 139       NaN
# 140       NaN
# 141       NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 139       Riyadh
# 140       Riyadh
# 141       Riyadh
# Name: Region, dtype: object)
# ('HCW', Case #
# 139       NaN
# 140       NaN
# 141       NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 139         Y
# 140       NaN
# 141         Y
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 139       OctRiyadh
# 140       OctRiyadh
# 141       OctRiyadh
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 139       NaN
# 140       NaN
# 141       NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 139       H
# 140       L
# 141       L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 139       NaN
# 140       NaN
# 141       NaN
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 139       2013-10-01 00:00:00
# 140       2013-10-01 00:00:00
# 141       2013-10-01 00:00:00
# Name: report_date, dtype: object)
# ('dates', Case #
# 139       2013-10-01 00:00:00
# 140       2013-10-01 00:00:00
# 141       2013-10-01 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 174       174
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 174       2013-12-13
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 174       NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 174       68
# Name: Age, dtype: float64)
# ('Sex', Case #
# 174       M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 174       UAE
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 174       Dead
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 174       NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 174       NaN
# Name: Region, dtype: object)
# ('HCW', Case #
# 174       NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 174       Y
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 174       OmanC
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 174       No hx of travel, contact, animals
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 174       NaN
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 174       2013-12-13 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 174       NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 174       2013-12-13 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 144       144
# 150       150
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 144       2013-10-11
# 150              NaN
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 144              NaN
# 150       2013-10-27
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 144       61
# 150       23
# Name: Age, dtype: float64)
# ('Sex', Case #
# 144       M
# 150       M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 144       Qatar
# 150       Qatar
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 144              Alive
# 150       Asymptomatic
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 144       NaN
# 150       NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 144       Qatar
# 150         NaN
# Name: Region, dtype: object)
# ('HCW', Case #
# 144       NaN
# 150       NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 144         Y
# 150       NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 144       Qatar1
# 150       Qatar1
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 144       No hx of travel. No contact w/ confirmed case....
# 150                                                     NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 144       H
# 150       L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 144       2013-10-11 00:00:00
# 150                       NaN
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 144                       NaN
# 150       2013-10-27 00:00:00
# Name: report_date, dtype: object)
# ('dates', Case #
# 144       2013-10-11 00:00:00
# 150       2013-10-27 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 153       153
# 167       167
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 153       2013-10-15
# 167              NaN
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 153              NaN
# 167       2013-11-22
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 153       61
# 167      NaN
# Name: Age, dtype: float64)
# ('Sex', Case #
# 153       F
# 167       F
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 153             France
# 167       Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 153       Alive
# 167       Alive
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 153       NaN
# 167       NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 153       NaN
# 167       NaN
# Name: Region, dtype: object)
# ('HCW', Case #
# 153       NaN
# 167       NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 153       NaN
# 167       NaN
# Name: Reported comorbidities, dtype: object)
# ...
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 133       75
# Name: Age, dtype: float64)
# ('Sex', Case #
# 133       F
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 133       Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 133       Dead
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 133       NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 133       Medina
# Name: Region, dtype: object)
# ('HCW', Case #
# 133       NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 133       Y
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 133       Unknown 7
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 133       NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 133       L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 133       NaN
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 133       2013-09-18 00:00:00
# Name: report_date, dtype: object)
# ('dates', Case #
# 133       2013-09-18 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 134       134
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 134       NaN
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 134       2013-09-18
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 134       35
# Name: Age, dtype: float64)
# ('Sex', Case #
# 134       M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 134       Saudi Arabia
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 134       Critical
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 134       NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 134       Medina
# Name: Region, dtype: object)
# ('HCW', Case #
# 134       NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 134       NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 134       Unknown 8
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 134       NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 134       H
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 134       NaN
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 134       2013-09-18 00:00:00
# Name: report_date, dtype: object)
# ('dates', Case #
# 134       2013-09-18 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 1         1
# 2         2
# Name: Case #, dtype: float64)
# ('Approx onset date', Case #
# 1         2012-04-01
# 2         2012-04-01
# Name: Approx onset date, dtype: object)
# ('Approx reporting date', Case #
# 1         NaN
# 2         NaN
# Name: Approx reporting date, dtype: object)
# ('Age', Case #
# 1         45
# 2         25
# Name: Age, dtype: float64)
# ('Sex', Case #
# 1         F
# 2         M
# Name: Sex, dtype: object)
# ('Probable infection place', Case #
# 1         Jordan
# 2         Jordan
# Name: Probable infection place, dtype: object)
# ('Health status', Case #
# 1         Dead
# 2         Dead
# Name: Health status, dtype: object)
# ('Approx death date', Case #
# 1         NaN
# 2         NaN
# Name: Approx death date, dtype: object)
# ('Region', Case #
# 1                  NaN
# 2         Bisha/Jeddah
# Name: Region, dtype: object)
# ('HCW', Case #
# 1         NaN
# 2         NaN
# Name: HCW, dtype: object)
# ('Reported comorbidities', Case #
# 1         NaN
# 2         NaN
# Name: Reported comorbidities, dtype: object)
# ('Cluster ID', Case #
# 1         hospital A
# 2         hospital A
# Name: Cluster ID, dtype: object)
# ('Notes', Case #
# 1         NaN
# 2         NaN
# Name: Notes, dtype: object)
# (' Zoonotic', Case #
# 1         H
# 2         L
# Name:  Zoonotic, dtype: object)
# ('onset_date', Case #
# 1         2012-04-01 00:00:00
# 2         2012-04-01 00:00:00
# Name: onset_date, dtype: object)
# ('report_date', Case #
# 1         NaN
# 2         NaN
# Name: report_date, dtype: object)
# ('dates', Case #
# 1         2012-04-01 00:00:00
# 2         2012-04-01 00:00:00
# Name: dates, dtype: object)
# ('Case #', Case #
# 3          3
# 4          4
# 5          5
# 6          6
# 13        13
# 12        12
# 14        14
# 17        17
# 25        25
# 27        27
# 26        26
# 44        44
# 50        50
# 58        58
# 60        60
# ...
# 160       160
# 154       154
# 159       159
# 161       161
# 169       169
# 175       175
# 171       171
# 170       170
# 172       172
# 173       173
# 176       176
# 177       177
# 178       178
# 179       179
# 181       181
# Name: Case #, Length: 82, dtype: float64)
# ('Approx onset date', Case #
# 3         2012-06-13
# 4         2012-09-03
# 5         2012-10-10
# 6         2012-10-12
# 13        2013-01-29
# 12        2013-02-05
# 14        2013-02-10
# 17        2013-03-19
# 25        2013-04-27
# 27        2013-04-28
# 26        2013-04-30
# 44        2013-05-15
# 50               NaN
# 58               NaN
# 60               NaN
# ...
# 160       2013-11-04
# 154              NaN
# 159       2013-11-07
# 161       2013-11-12
# 169              NaN
# 175       2013-12-17
# 171              NaN
# 170              NaN
# 172              NaN
# 173              NaN
# 176              NaN
# 177              NaN
# 178              NaN
# 179              NaN
# 181       2013-12-27
# Name: Approx onset date, Length: 82, dtype: object)
# ('Approx reporting date', Case #
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 13               NaN
# 12               NaN
# 14               NaN
# 17               NaN
# 25               NaN
# 27               NaN
# 26               NaN
# 44               NaN
# 50        2013-05-29
# 58        2013-06-11
# 60        2013-06-14
# ...
# 160              NaN
# 154       2013-11-07
# 159              NaN
# 161              NaN
# 169       2013-12-06
# 175       2013-12-25
# 171       2013-12-20
# 170       2013-12-20
# 172       2013-12-20
# 173       2013-12-20
# 176       2013-12-25
# 177       2013-12-25
# 178       2013-12-25
# 179       2013-12-25
# 181              NaN
# Name: Approx reporting date, Length: 82, dtype: object)
# ('Age', Case #
# 3         60
# 4         49
# 5         45
# 6         45
# 13       NaN
# 12       NaN
# 14        69
# 17        73
# 25        53
# 27        33
# 26        50
# 44        63
# 50        61
# 58        21
# 60        68
# ...
# 160       61
# 154       75
# 159       52
# 161       73
# 169       51
# 175       57
# 171      NaN
# 170      NaN
# 172       53
# 173       73
# 176       73
# 177       43
# 178       35
# 179       27
# 181       33
# Name: Age, Length: 82, dtype: float64)
# ('Sex', Case #
# 3         M
# 4         M
# 5         M
# 6         M
# 13        F
# 12        F
# 14        M
# 17        M
# 25        F
# 27        M
# 26        M
# 44        M
# 50        M
# 58        M
# 60        F
# ...
# 160         M
# 154       NaN
# 159         M
# 161         F
# 169       NaN
# 175         M
# 171         F
# 170         F
# 172         M
# 173         M
# 176         M
# 177       NaN
# 178       NaN
# 179       NaN
# 181         M
# Name: Sex, Length: 82, dtype: object)
# ('Probable infection place', Case #
# 3           Saudi Arabia
# 4           Saudi Arabia
# 5           Saudi Arabia
# 6                  Qatar
# 13          Saudi Arabia
# 12        United Kingdom
# 14          Saudi Arabia
# 17                   UAE
# 25          Saudi Arabia
# 27          Saudi Arabia
# 26          Saudi Arabia
# 44          Saudi Arabia
# 50          Saudi Arabia
# 58          Saudi Arabia
# 60          Saudi Arabia
# ...
# 160              Qatar
# 154                UAE
# 159             Kuwait
# 161       Saudi Arabia
# 169       Saudi Arabia
# 175       Saudi Arabia
# 171       Saudi Arabia
# 170       Saudi Arabia
# 172       Saudi Arabia
# 173       Saudi Arabia
# 176       Saudi Arabia
# 177       Saudi Arabia
# 178       Saudi Arabia
# 179       Saudi Arabia
# 181                UAE
# Name: Probable infection place, Length: 82, dtype: object)
# ('Health status', Case #
# 3          Dead
# 4         Alive
# 5         Alive
# 6         Alive
# 13         Dead
# 12         Mild
# 14         Dead
# 17         Dead
# 25         Dead
# 27        Alive
# 26        Alive
# 44         Dead
# 50        Alive
# 58         Dead
# 60         Dead
# ...
# 160               Dead
# 154               Dead
# 159           Critical
# 161               Dead
# 169           Critical
# 175           Critical
# 171       Asymptomatic
# 170       Asymptomatic
# 172           Critical
# 173               Dead
# 176               Dead
# 177       Asymptomatic
# 178       Asymptomatic
# 179       Asymptomatic
# 181           Critical
# Name: Health status, Length: 82, dtype: object)
# ('Approx death date', Case #
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 13        2013-02-10
# 12               NaN
# 14        2013-02-19
# 17        2013-03-26
# 25        2013-07-06
# 27               NaN
# 26               NaN
# 44        2013-05-20
# 50               NaN
# 58        2013-05-11
# 60               NaN
# ...
# 160       2013-11-15
# 154       2013-11-08
# 159              NaN
# 161       2013-11-18
# 169              NaN
# 175              NaN
# 171              NaN
# 170              NaN
# 172              NaN
# 173       2013-12-18
# 176              NaN
# 177              NaN
# 178              NaN
# 179              NaN
# 181              NaN
# Name: Approx death date, Length: 82, dtype: object)
# ('Region', Case #
# 3                 Jeddah
# 4                    NaN
# 5                 Riyadh
# 6                    NaN
# 13                   NaN
# 12                   NaN
# 14                   NaN
# 17                   NaN
# 25                   NaN
# 27                   NaN
# 26                   NaN
# 44             Al-Qaseem
# 50                Riyadh
# 58        Hafar Al-Batin
# 60                 Mecca
# ...
# 160             NaN
# 154       Abu Dhabi
# 159          Adalan
# 161          Riyadh
# 169          AlJouf
# 175          Riyadh
# 171             NaN
# 170             NaN
# 172             NaN
# 173             NaN
# 176          Riyadh
# 177          Riyadh
# 178          Riyadh
# 179          Riyadh
# 181             NaN
# Name: Region, Length: 82, dtype: object)
# ('HCW', Case #
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 13        NaN
# 12        NaN
# 14        NaN
# 17        NaN
# 25        NaN
# 27        NaN
# 26        NaN
# 44        NaN
# 50        NaN
# 58        NaN
# 60        NaN
# ...
# 160       NaN
# 154       NaN
# 159       NaN
# 161       NaN
# 169       NaN
# 175       NaN
# 171         Y
# 170         Y
# 172       NaN
# 173       NaN
# 176       NaN
# 177         Y
# 178         Y
# 179         Y
# 181         Y
# Name: HCW, Length: 82, dtype: object)
# ('Reported comorbidities', Case #
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 13        NaN
# 12        NaN
# 14        NaN
# 17        NaN
# 25          Y
# 27          Y
# 26          Y
# 44          Y
# 50          Y
# 58        NaN
# 60          Y
# ...
# 160         Y
# 154         Y
# 159         Y
# 161         Y
# 169         Y
# 175         Y
# 171       NaN
# 170       NaN
# 172         Y
# 173         Y
# 176         Y
# 177       NaN
# 178       NaN
# 179       NaN
# 181       NaN
# Name: Reported comorbidities, Length: 82, dtype: object)
# ('Cluster ID', Case #
# 3         single
# 4         single
# 5         single
# 6         single
# 13        single
# 12        single
# 14        single
# 17        single
# 25        single
# 27        single
# 26        single
# 44        single
# 50        single
# 58        single
# 60        single
# ...
# 160       single
# 154       single
# 159       single
# 161       single
# 169       single
# 175       single
# 171       single
# 170       single
# 172       single
# 173       single
# 176       single
# 177       single
# 178       single
# 179       single
# 181       single
# Name: Cluster ID, Length: 82, dtype: object)
# ('Notes', Case #
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 13                            NaN
# 12                            NaN
# 14                            NaN
# 17        Hospitalized in Germany
# 25                            NaN
# 27                            NaN
# 26                            NaN
# 44                            NaN
# 50                            NaN
# 58                            NaN
# 60                            NaN
# ...
# 160                                    hx of animal contact
# 154               Onset in October. Cancer. Citizen of Oman
# 159       kuwait cases supposedly not related; travel hx...
# 161                                                     NaN
# 169                                                     NaN
# 175                       No hx of travel, contact, animals
# 171                                                     NaN
# 170                                                     NaN
# 172                                                     NaN
# 173                                                     NaN
# 176                       No hx of travel, contact, animals
# 177                                                     NaN
# 178                                                     NaN
# 179                                                     NaN
# 181                                                     NaN
# Name: Notes, Length: 82, dtype: object)
# (' Zoonotic', Case #
# 3         H
# 4         H
# 5         H
# 6         H
# 13        H
# 12        H
# 14        H
# 17        H
# 25        H
# 27        H
# 26        H
# 44        H
# 50        H
# 58        H
# 60        H
# ...
# 160       NaN
# 154         H
# 159       NaN
# 161       NaN
# 169       NaN
# 175       NaN
# 171       NaN
# 170       NaN
# 172       NaN
# 173       NaN
# 176       NaN
# 177       NaN
# 178       NaN
# 179       NaN
# 181       NaN
# Name:  Zoonotic, Length: 82, dtype: object)
# ('onset_date', Case #
# 3         2012-06-13 00:00:00
# 4         2012-09-03 00:00:00
# 5         2012-10-10 00:00:00
# 6         2012-10-12 00:00:00
# 13        2013-01-29 00:00:00
# 12        2013-02-05 00:00:00
# 14        2013-02-10 00:00:00
# 17        2013-03-19 00:00:00
# 25        2013-04-27 00:00:00
# 27        2013-04-28 00:00:00
# 26        2013-04-30 00:00:00
# 44        2013-05-15 00:00:00
# 50                        NaN
# 58                        NaN
# 60                        NaN
# ...
# 160       2013-11-04 00:00:00
# 154                       NaN
# 159       2013-11-07 00:00:00
# 161       2013-11-12 00:00:00
# 169                       NaN
# 175       2013-12-17 00:00:00
# 171                       NaN
# 170                       NaN
# 172                       NaN
# 173                       NaN
# 176                       NaN
# 177                       NaN
# 178                       NaN
# 179                       NaN
# 181       2013-12-27 00:00:00
# Name: onset_date, Length: 82, dtype: object)
# ('report_date', Case #
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 13                        NaN
# 12                        NaN
# 14                        NaN
# 17                        NaN
# 25                        NaN
# 27                        NaN
# 26                        NaN
# 44                        NaN
# 50        2013-05-29 00:00:00
# 58        2013-06-11 00:00:00
# 60        2013-06-14 00:00:00
# ...
# 160                       NaN
# 154       2013-11-07 00:00:00
# 159                       NaN
# 161                       NaN
# 169       2013-12-06 00:00:00
# 175       2013-12-25 00:00:00
# 171       2013-12-20 00:00:00
# 170       2013-12-20 00:00:00
# 172       2013-12-20 00:00:00
# 173       2013-12-20 00:00:00
# 176       2013-12-25 00:00:00
# 177       2013-12-25 00:00:00
# 178       2013-12-25 00:00:00
# 179       2013-12-25 00:00:00
# 181                       NaN
# Name: report_date, Length: 82, dtype: object)
# ('dates', Case #
# 3        2012-06-13 00:00:00
# 4        2012-09-03 00:00:00
# 5        2012-10-10 00:00:00
# 6        2012-10-12 00:00:00
# 13       2013-01-29 00:00:00
# 12       2013-02-05 00:00:00
# 14       2013-02-10 00:00:00
# 17       2013-03-19 00:00:00
# 25       2013-04-27 00:00:00
# 27       2013-04-28 00:00:00
# 26       2013-04-30 00:00:00
# 44       2013-05-15 00:00:00
# 50       2013-05-29 00:00:00
# 58       2013-06-11 00:00:00
# 60       2013-06-14 00:00:00
# ...
# 160      2013-11-04 00:00:00
# 154      2013-11-07 00:00:00
# 159      2013-11-07 00:00:00
# 161      2013-11-12 00:00:00
# 169      2013-12-06 00:00:00
# 175      2013-12-17 00:00:00
# 171      2013-12-20 00:00:00
# 170      2013-12-20 00:00:00
# 172      2013-12-20 00:00:00
# 173      2013-12-20 00:00:00
# 176      2013-12-25 00:00:00
# 177      2013-12-25 00:00:00
# 178      2013-12-25 00:00:00
# 179      2013-12-25 00:00:00
# 181      2013-12-27 00:00:00
# Name: dates, Length: 82, dtype: object)

# %%
clusters.head(20)
# Out:
#          case_id            color  index_node  source_node                time
# case_id
# 51            51        Cluster A          51           51 2013-05-31 00:00:00
# 52            52        Cluster A          51           51 2013-06-01 00:00:00
# 53            53        Cluster A          51           51 2013-06-01 00:00:00
# 114          114        Cluster E         114          114 2013-08-15 00:00:00
# 115          115        Cluster E         114          114 2013-08-21 00:00:00
# 112          112        Cluster E         114          115 2013-09-01 00:00:00
# 163          163              Dec         163          163 2013-11-09 00:00:00
# 168          168             Deec         168          168 2013-12-06 00:00:00
# 33            33  Eastern cluster          33           33 2013-04-06 00:00:00
# 18            18  Eastern cluster          33           33 2013-04-14 00:00:00
# 29            29  Eastern cluster          33           33 2013-04-15 00:00:00
# 19            19  Eastern cluster          33           33 2013-04-17 00:00:00
# 20            20  Eastern cluster          33           33 2013-04-17 00:00:00
# 28            28  Eastern cluster          33           33 2013-04-19 00:00:00
# 23            23  Eastern cluster          33           33 2013-04-22 00:00:00
# 21            21  Eastern cluster          33           33 2013-04-22 00:00:00
# 22            22  Eastern cluster          33           33 2013-04-22 00:00:00
# 24            24  Eastern cluster          33           33 2013-04-22 00:00:00
# 31            31  Eastern cluster          33           33 2013-04-23 00:00:00
# 36            36  Eastern cluster          33           33 2013-04-24 00:00:00

# %%
clusters.to_pickle('../cluster_network.pkl')

# %%
def plot_cluster(df, clusters, cluster_id, date_col):
    
    cols = cycle([color for i, color in enumerate(plt.rcParams['axes.color_cycle'])])
    
    clusters = _group_clusters(dat, 'Cluster ID', 'dates')
    
    fig, ax = plt.subplots(figsize=(12, 10))
    ax.xaxis_date()
    ax.set_aspect('auto')
    axprop =  ax.axis()
    
    grpnames = [key for key, group in clusters if len(group) > 1]
    plt.ylim(1, len(grpnames))
    plt.yticks(np.arange(len(grpnames)), grpnames)
    
    xtog = timedelta(((10*axprop[1]-axprop[0])/axprop[1]), 0, 0)
    counter = 0
    
    for key, group in clusters:
        if len(group) > 1:
            color = next(cols)
            casenums = cycle([int(num) for num in group['Case #']])
            
            positions = []
            for casedate in group.dates.order():
                x1 = casedate
                x2 = casedate + xtog
                positions.append(x2)
                
                y1 = np.array([counter, counter])
                y2 = y1 + 1
                
                plt.fill_between([x1, x2], y1, y2, color=color, alpha=.3)
                
                yposition = y1[0] + .5
                
                try:
                    if x1 <= positions[-2]:
                        yposition = yposition + np.random.uniform(-.4, .4, 1)
                except:
                    pass
                    
                textspot= x1 + timedelta((x2 - x1).days/2.0, 0, 0)
                
                plt.text(textspot, yposition, next(casenums), horizontalalignment='center', 
                         verticalalignment='center', fontsize=9)    
                
            counter += 1
            
    fig.autofmt_xdate()
    fig.tight_layout()
    
    return fig, ax

# %%
fig, ax = plot_cluster(dat, clusters, 'Cluster ID', 'dates')
ax.set_title("MERS-CoV clusters")
fig.savefig('../cluster_checkerboard.png')
