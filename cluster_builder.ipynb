# %%
from itertools import cycle
from matplotlib import pyplot as plt
from random import choice
import numpy as np
from datetime import datetime, timedelta
import pandas as pd

# %%
def date_convert(x):
    try:
        y = datetime.strptime(x, "%Y-%m-%d")
    except:
        y = np.nan
        
    return y

# %%
dat = pd.read_csv("/Users/cmrivers/Downloads/Line list & epi stats - Line list.csv", parse_dates=True)
dat.index = dat['Cluster ID']

# %%
dat['onset_date'] = dat['Approx onset date'].map(date_convert)
dat['report_date'] = dat['Approx reporting date'].map(date_convert)
dat['dates'] = dat['onset_date'].combine_first(dat['report_date'])

# %%
def _group_clusters(df, cluster_id, date_col):
    clusters = df[df[cluster_id].notnull()]
    clusters = df[df[date_col].notnull()]
    
    groups = clusters.groupby(clusters[cluster_id])
    
    return groups

# %% [markdown]
# http://stackoverflow.com/questions/8772421/how-to-plot-events-on-time-on-using-matplotlib

# %%
def cluster_builder(df, cluster_id, case_id, date_col, inc_mean, inc_sd):
    '''
    '''
    clusters = _group_clusters(df, cluster_id, date_col)
    grpnames = np.unique(df[cluster_id]).dropna().values
    
    mmin = timedelta(inc_mean - 3 * inc_sd, 0)
    mmax = timedelta(inc_mean + 3 * inc_sd, 0)
    
    mx = []
    for key, group in clusters:
        row = [tmp[1:3] for tmp in group[['Case #', 'dates']].sort('dates').itertuples()]
        mx.append(row)

    network = []
    for ix in range(0, len(mx)):
        for inx in range(0, len(mx[ix])):
            index_node = mx[ix][0][0]
            source_node = index_node
            case_id = mx[ix][inx][0]
            time = mx[ix][inx][1]
            
            if len(mx[ix]) > 1:
               if mx[ix][inx][1] - mx[ix][inx-1][1] > mmin:
                    source_node = mx[ix][inx-1][0]
        
            result = (case_id, index_node, source_node, time)
            network.append(result)
            
    df_out = pd.DataFrame(network, columns=['case_id', 'index_node', 'source_node', 'time'])
    df_out.index = df_out.case_id
    
    return clusters, df_out

# %%
clusters, mx = cluster_builder(dat, 'Cluster ID', 'Case #', 'dates', 7, 5)
plt.savefig('/Users/cmrivers/Desktop/cluster_builder.png')
mx
# Out:
#          case_id  index_node  source_node                time
# case_id
# 51            51          51           53 2013-05-31 00:00:00
# 52            52          51           51 2013-06-01 00:00:00
# 53            53          51           52 2013-06-01 00:00:00
# 114          114         114          114 2013-08-15 00:00:00
# 115          115         114          114 2013-08-21 00:00:00
# 112          112         114          115 2013-09-01 00:00:00
# 33            33          33           33 2013-04-06 00:00:00
# 18            18          33           33 2013-04-14 00:00:00
# 29            29          33           18 2013-04-15 00:00:00
# 19            19          33           29 2013-04-17 00:00:00
# 20            20          33           19 2013-04-17 00:00:00
# 28            28          33           20 2013-04-19 00:00:00
# 23            23          33           28 2013-04-22 00:00:00
# 21            21          33           23 2013-04-22 00:00:00
# 22            22          33           21 2013-04-22 00:00:00
# 24            24          33           22 2013-04-22 00:00:00
# 31            31          33           24 2013-04-23 00:00:00
# 36            36          33           31 2013-04-24 00:00:00
# 35            35          33           36 2013-04-25 00:00:00
# 37            37          33           35 2013-04-26 00:00:00
# 41            41          33           37 2013-04-28 00:00:00
# 32            32          33           41 2013-04-29 00:00:00
# 30            30          33           32 2013-05-01 00:00:00
# 38            38          33           30 2013-05-07 00:00:00
# 45            45          33           38 2013-05-12 00:00:00
# 46            46          33           45 2013-05-17 00:00:00
# 49            49          33           46 2013-05-18 00:00:00
# 48            48          33           49 2013-05-19 00:00:00
# 47            47          33           48 2013-05-24 00:00:00
# 54            54          33           47 2013-05-29 00:00:00
# 55            55          33           54 2013-06-04 00:00:00
# 57            57          33           55 2013-06-11 00:00:00
# 56            56          33           57 2013-06-11 00:00:00
# 62            62          33           56 2013-06-17 00:00:00
# 70            70          33           62 2013-06-21 00:00:00
# 65            65          33           70 2013-06-22 00:00:00
# 75            75          33           65 2013-06-23 00:00:00
# 76            76          33           75 2013-06-23 00:00:00
# 77            77          33           76 2013-06-23 00:00:00
# 90            90          33           77 2013-07-11 00:00:00
# 9              9           9            9 2012-10-01 00:00:00
# 8              8           9            9 2012-10-28 00:00:00
# 7              7           9            8 2012-11-05 00:00:00
# 10            10          10           10 2013-01-24 00:00:00
# 11            11          10           10 2013-02-06 00:00:00
# 42            42          42           42 2013-04-20 00:00:00
# 43            43          42           42 2013-04-20 00:00:00
# 116          116          42           43 2013-05-01 00:00:00
# 106          106         106          106 2013-08-08 00:00:00
# 107          107         106          106 2013-08-30 00:00:00
# 108          108         106          107 2013-08-30 00:00:00
# 109          109         106          108 2013-09-01 00:00:00
# 110          110         106          109 2013-09-01 00:00:00
# 15            15          15           16 2013-02-24 00:00:00
# 16            16          15           15 2013-03-02 00:00:00
# 34            34          34           34 2013-04-27 00:00:00
# 83            83          83           84 2013-07-17 00:00:00
# 84            84          83           83 2013-07-17 00:00:00
# 39            39          39           40 2013-05-02 00:00:00
# 40            40          39           39 2013-05-08 00:00:00
# 66            66          66           68 2013-06-22 00:00:00
# 67            67          66           66 2013-06-22 00:00:00
# 68            68          66           67 2013-06-22 00:00:00
# 82            82          82           88 2013-07-12 00:00:00
# 85            85          82           82 2013-07-18 00:00:00
# 86            86          82           85 2013-07-18 00:00:00
# 87            87          82           86 2013-07-18 00:00:00
# 88            88          82           87 2013-07-18 00:00:00
# 101          101         101          101 2013-08-22 00:00:00
# 113          113         113          113 2013-08-23 00:00:00
# 121          121         121          121 2013-09-08 00:00:00
# 124          124         124          124 2013-09-08 00:00:00
# 2              2           2            1 2012-04-01 00:00:00
# 1              1           2            2 2012-04-01 00:00:00

# %%
mx.save('./network.pkl')

# %%
def plot_cluster():
    fig, ax = plt.subplots()
    fig.set_size_inches(8, 5)
    ax.xaxis_date()
    ax.set_aspect('auto')
    axprop =  plt.axis()
    fig.autofmt_xdate()
    
    plt.ylim(1, len(grpnames))
    plt.yticks(np.arange(len(grpnames)), grpnames)
    
    for key, group in clusters:
        for date in date_lst:
            xtog = timedelta(((10*axprop[1]-axprop[0])/axprop[1]), 0, 0)
            x1 = [date, date+xtog]
    
            for i in range(len(grpnames)):
                if key == grpnames[i]:
                    y1 = np.array([i, i])
                    y2 = y1+0.5
                    plt.fill_between(x1, y1, y2, color=color, alpha=.3)
                    
                    xspot= x1[0] + timedelta((x1[1] - x1[0]).days/2.0, 0, 0)
                    
                    plt.text(xspot, y1[1]+.25, next(casenums), horizontalalignment='center', verticalalignment='center', fontsize=9)
                    
    return fig
