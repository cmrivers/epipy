# %%
from itertools import cycle
from matplotlib import pyplot as plt
from random import choice
import numpy as np
from datetime import datetime, timedelta
import pandas as pd

# %%
def date_convert(x):
    try:
        y = datetime.strptime(x, "%Y-%m-%d")
    except:
        y = np.nan
        
    return y

# %%
dat = pd.read_csv("/Users/cmrivers/Downloads/Line list & epi stats - Line list.csv", parse_dates=True)
dat.index = dat['Cluster ID']

# %%
dat
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 136 entries, hospital A to Group 2
# Data columns:
# Unnamed: 0                  0  non-null values
# Case #                      136  non-null values
# Approx onset date           66  non-null values
# Approx reporting date       73  non-null values
# Age                         129  non-null values
# Sex                         121  non-null values
# Probable infection place    134  non-null values
# Health status               132  non-null values
# Approx death date           33  non-null values
# Region                      101  non-null values
# Notes                       22  non-null values
# HCW                         18  non-null values
# Reported comorbidities      61  non-null values
# Cluster ID                  81  non-null values
# dtypes: float64(2), int64(1), object(11)

# %%
dat['onset_date'] = dat['Approx onset date'].map(date_convert)
dat['report_date'] = dat['Approx reporting date'].map(date_convert)
dat['dates'] = dat['onset_date'].combine_first(dat['report_date'])

# %%
def _group_clusters(df, cluster_id, date_col):
    clusters = df[df[cluster_id].notnull()]
    clusters = df[df[date_col].notnull()]
    
    groups = clusters.groupby(clusters[cluster_id])
    
    return groups

# %% [markdown]
# http://stackoverflow.com/questions/8772421/how-to-plot-events-on-time-on-using-matplotlib

# %%
def cluster_builder(df, cluster_id, case_id, date_col, color_col, inc_mean, inc_sd):
    '''
    '''
    clusters = _group_clusters(df, cluster_id, date_col)
    grpnames = np.unique(df[cluster_id]).dropna().values
    
    mmin = timedelta(inc_mean - (1 * inc_sd), 0)
    mmax = timedelta(inc_mean + (1 * inc_sd), 0)
    
    mx = []
    for key, group in clusters:
        row = [tmp[1:4] for tmp in group[[case_id, date_col, color_col]].sort('dates').itertuples()]
        mx.append(row)

    network = []
    for ix in range(0, len(mx)):
        for inx in range(0, len(mx[ix])):
            index_node = mx[ix][0][0]
            source_node = index_node
            case_id = mx[ix][inx][0]
            time = mx[ix][inx][1]
            color = mx[ix][inx][2]
            
            if len(mx[ix]) > 1:
               if mx[ix][inx][1] - mx[ix][inx-1][1] > mmin:
                    source_node = mx[ix][inx-1][0]
        
            result = (case_id, color, index_node, source_node, time)
            network.append(result)
            
    df_out = pd.DataFrame(network, columns=['case_id', 'color', 'index_node', 'source_node', 'time'])
    df_out.index = df_out.case_id
    
    return clusters, df_out

# %%
clusters, mx = cluster_builder(dat, 'Cluster ID', 'Case #', 'dates', 'Health status', 7, 5)
plt.savefig('/Users/cmrivers/Desktop/cluster_builder.png')
mx.head(40)
# Out:
#          case_id         color  index_node  source_node                 time
# case_id
# 51            51         Alive          51           51  2013-05-31 00:00:00
# 52            52         Alive          51           51  2013-06-01 00:00:00
# 53            53         Alive          51           51  2013-06-01 00:00:00
# 114          114          Dead         114          114  2013-08-15 00:00:00
# 115          115          Dead         114          114  2013-08-21 00:00:00
# 112          112      Critical         114          115  2013-09-01 00:00:00
# 33            33     Recovered          33           33  2013-04-06 00:00:00
# 18            18          Dead          33           33  2013-04-14 00:00:00
# 29            29          Dead          33           33  2013-04-15 00:00:00
# 19            19          Dead          33           33  2013-04-17 00:00:00
# 20            20          Dead          33           33  2013-04-17 00:00:00
# 28            28          Dead          33           33  2013-04-19 00:00:00
# 23            23          Dead          33           28  2013-04-22 00:00:00
# 21            21      Critical          33           33  2013-04-22 00:00:00
# 22            22          Dead          33           33  2013-04-22 00:00:00
# 24            24          Dead          33           33  2013-04-22 00:00:00
# 31            31          Dead          33           33  2013-04-23 00:00:00
# 36            36      Critical          33           33  2013-04-24 00:00:00
# 35            35          Dead          33           33  2013-04-25 00:00:00
# 37            37      Critical          33           33  2013-04-26 00:00:00
# 41            41          Dead          33           33  2013-04-28 00:00:00
# 32            32         Alive          33           33  2013-04-29 00:00:00
# 30            30      Critical          33           33  2013-05-01 00:00:00
# 38            38         Alive          33           30  2013-05-07 00:00:00
# 45            45          Dead          33           38  2013-05-12 00:00:00
# 46            46      Critical          33           45  2013-05-17 00:00:00
# 49            49          Dead          33           33  2013-05-18 00:00:00
# 48            48          Dead          33           33  2013-05-19 00:00:00
# 47            47     Recovered          33           48  2013-05-24 00:00:00
# 54            54         Alive          33           47  2013-05-29 00:00:00
# 55            55          Dead          33           54  2013-06-04 00:00:00
# 56            56         Alive          33           55  2013-06-11 00:00:00
# 57            57          Dead          33           33  2013-06-11 00:00:00
# 62            62         Alive          33           57  2013-06-17 00:00:00
# 70            70          Dead          33           62  2013-06-21 00:00:00
# 65            65     Recovered          33           33  2013-06-22 00:00:00
# 75            75  Asymptomatic          33           33  2013-06-23 00:00:00
# 76            76  Asymptomatic          33           33  2013-06-23 00:00:00
# 77            77         Alive          33           33  2013-06-23 00:00:00
# 90            90      Critical          33           77  2013-07-11 00:00:00

# %%
clusters[['number', 'severity']].head()
# Out:
#                                  Unnamed: 0  Case # Approx onset date  \
# Cluster ID      Cluster ID
# Cluster A       Cluster A               NaN      51               NaN
#                 Cluster A               NaN      52               NaN
#                 Cluster A               NaN      53               NaN
# Cluster E       Cluster E               NaN     112        2013-09-01
#                 Cluster E               NaN     114        2013-08-15
#                 Cluster E               NaN     115        2013-08-21
# Eastern cluster Eastern cluster         NaN      18        2013-04-14
#                 Eastern cluster         NaN      19        2013-04-17
#                 Eastern cluster         NaN      20        2013-04-17
#                 Eastern cluster         NaN      21        2013-04-22
#                 Eastern cluster         NaN      22        2013-04-22
# Family A        Family A                NaN       7        2012-11-05
#                 Family A                NaN       8        2012-10-28
#                 Family A                NaN       9        2012-10-01
# Family B        Family B                NaN      10        2013-01-24
#                 Family B                NaN      11        2013-02-06
# Family C        Family C                NaN      42               NaN
#                 Family C                NaN      43               NaN
#                 Family C                NaN     116        2013-05-01
# Family D        Family D                NaN     106        2013-08-08
#                 Family D                NaN     107               NaN
#                 Family D                NaN     108               NaN
#                 Family D                NaN     109               NaN
#                 Family D                NaN     110               NaN
# Group 2         Group 2                 NaN      15        2013-02-24
#                 Group 2                 NaN      16        2013-03-02
#                 Group 2                 NaN     136        2013-01-30
# Group 6         Group 6                 NaN      34        2013-04-27
# Group A         Group A                 NaN      83               NaN
#                 Group A                 NaN      84               NaN
# Hospital B      Hospital B              NaN      39        2013-05-02
#                 Hospital B              NaN      40        2013-05-08
# Hospital C      Hospital C              NaN      66               NaN
#                 Hospital C              NaN      67               NaN
#                 Hospital C              NaN      68               NaN
# UAE Hospital    UAE Hospital            NaN      82               NaN
#                 UAE Hospital            NaN      85               NaN
#                 UAE Hospital            NaN      86               NaN
#                 UAE Hospital            NaN      87               NaN
#                 UAE Hospital            NaN      88               NaN
# Unknown 2       Unknown 2               NaN     101               NaN
# Unknown 3       Unknown 3               NaN     113        2013-08-23
# Unknown 4       Unknown 4               NaN     121               NaN
# Unknown 5       Unknown 5               NaN     124               NaN
# Unknown 6       Unknown 6               NaN     129               NaN
#                 Unknown 6               NaN     130               NaN
#                 Unknown 6               NaN     131               NaN
#                 Unknown 6               NaN     132               NaN
# Unknown 7       Unknown 7               NaN     133               NaN
# Unknown 8       Unknown 8               NaN     134               NaN
# hospital A      hospital A              NaN       1        2012-04-01
#                 hospital A              NaN       2        2012-04-01
#
#                                 Approx reporting date  Age  Sex  \
# Cluster ID      Cluster ID
# Cluster A       Cluster A                  2013-05-31   45    M
#                 Cluster A                  2013-06-01    2    F
#                 Cluster A                  2013-06-01   40    F
# Cluster E       Cluster E                         NaN   30    M
#                 Cluster E                         NaN   41    F
#                 Cluster E                         NaN   79    F
# Eastern cluster Eastern cluster                   NaN   59    M
#                 Eastern cluster                   NaN   24    M
#                 Eastern cluster                   NaN   87    M
#                 Eastern cluster                   NaN   58    M
#                 Eastern cluster                   NaN   94    M
# Family A        Family A                          NaN   31    M
#                 Family A                          NaN   39    M
#                 Family A                          NaN  NaN    M
# Family B        Family B                          NaN   60    M
#                 Family B                          NaN  NaN    M
# Family C        Family C                   2013-04-20   35    F
#                 Family C                   2013-04-20   34    M
#                 Family C                          NaN   66    M
# Family D        Family D                          NaN   38    M
#                 Family D                   2013-08-30   16    M
#                 Family D                   2013-08-30    7    F
#                 Family D                   2013-09-01   26  NaN
#                 Family D                   2013-09-01   19  NaN
# Group 2         Group 2                           NaN   39    M
#                 Group 2                           NaN   40    M
#                 Group 2                           NaN   51    M
# Group 6         Group 6                           NaN   50    M
# Group A         Group A                    2013-07-17   26    M
#                 Group A                    2013-07-17   42    F
# Hospital B      Hospital B                        NaN   45    M
#                 Hospital B                        NaN   43    F
# Hospital C      Hospital C                 2013-06-22   29    F
#                 Hospital C                 2013-06-22   39    F
#                 Hospital C                 2013-06-22   45    F
# UAE Hospital    UAE Hospital               2013-07-12   82    M
#                 UAE Hospital               2013-07-18   28    M
#                 UAE Hospital               2013-07-18   30    F
#                 UAE Hospital               2013-07-18   30    F
#                 UAE Hospital               2013-07-18   40    F
# Unknown 2       Unknown 2                  2013-08-22   55    M
# Unknown 3       Unknown 3                         NaN   47    M
# Unknown 4       Unknown 4                  2013-09-08   74    F
# Unknown 5       Unknown 5                  2013-09-08   74    M
# Unknown 6       Unknown 6                  2013-09-11   51    F
#                 Unknown 6                  2013-09-11   47    F
#                 Unknown 6                  2013-09-11   39    F
#                 Unknown 6                  2013-09-11   38    M
# Unknown 7       Unknown 7                  2013-09-18   75    F
# Unknown 8       Unknown 8                  2013-09-18   35    M
# hospital A      hospital A                        NaN   45    F
#                 hospital A                        NaN   25    M
#
#                                 Probable infection place Health status  \
# Cluster ID      Cluster ID
# Cluster A       Cluster A                          Italy         Alive
#                 Cluster A                          Italy         Alive
#                 Cluster A                          Italy         Alive
# Cluster E       Cluster E                   Saudi Arabia      Critical
#                 Cluster E                   Saudi Arabia          Dead
#                 Cluster E                   Saudi Arabia          Dead
# Eastern cluster Eastern cluster             Saudi Arabia          Dead
#                 Eastern cluster             Saudi Arabia          Dead
#                 Eastern cluster             Saudi Arabia          Dead
#                 Eastern cluster             Saudi Arabia      Critical
#                 Eastern cluster             Saudi Arabia          Dead
# Family A        Family A                    Saudi Arabia         Alive
#                 Family A                    Saudi Arabia          Dead
#                 Family A                    Saudi Arabia          Dead
# Family B        Family B                    Saudi Arabia          Dead
#                 Family B                  United Kingdom          Dead
# Family C        Family C                    Saudi Arabia          Mild
#                 Family C                    Saudi Arabia          Mild
#                 Family C                         Tunisia          Dead
# Family D        Family D                    Saudi Arabia          Dead
#                 Family D                    Saudi Arabia  Asymptomatic
#                 Family D                    Saudi Arabia  Asymptomatic
#                 Family D                             NaN     Recovered
#                 Family D                             NaN     Recovered
# Group 2         Group 2                     Saudi Arabia          Dead
#                 Group 2                     Saudi Arabia          Mild
#                 Group 2                     Saudi Arabia          Dead
# Group 6         Group 6                           France           NaN
# Group A         Group A                     Saudi Arabia          Mild
#                 Group A                     Saudi Arabia          Mild
# Hospital B      Hospital B                  Saudi Arabia      Critical
#                 Hospital B                  Saudi Arabia         Alive
# Hospital C      Hospital C                  Saudi Arabia  Asymptomatic
#                 Hospital C                  Saudi Arabia  Asymptomatic
#                 Hospital C                  Saudi Arabia         Alive
# UAE Hospital    UAE Hospital                         UAE      Critical
#                 UAE Hospital                         UAE  Asymptomatic
#                 UAE Hospital                         UAE  Asymptomatic
#                 UAE Hospital                         UAE          Mild
#                 UAE Hospital                         UAE          Mild
# Unknown 2       Unknown 2                   Saudi Arabia  Asymptomatic
# Unknown 3       Unknown 3                   Saudi Arabia      Critical
# Unknown 4       Unknown 4                   Saudi Arabia      Critical
# Unknown 5       Unknown 5                   Saudi Arabia          Dead
# Unknown 6       Unknown 6                   Saudi Arabia         Alive
#                 Unknown 6                   Saudi Arabia          Mild
#                 Unknown 6                   Saudi Arabia          Mild
#                 Unknown 6                   Saudi Arabia         Alive
# Unknown 7       Unknown 7                   Saudi Arabia          Dead
# Unknown 8       Unknown 8                   Saudi Arabia      Critical
# hospital A      hospital A                        Jordan          Dead
#                 hospital A                        Jordan          Dead
#
#                                 Approx death date          Region  \
# Cluster ID      Cluster ID
# Cluster A       Cluster A                     NaN             NaN
#                 Cluster A                     NaN             NaN
#                 Cluster A                     NaN             NaN
# Cluster E       Cluster E                     NaN          Riyadh
#                 Cluster E              2013-08-31          Riyadh
#                 Cluster E              2013-09-02  Hafar Al-batin
# Eastern cluster Eastern cluster        2013-03-19         Eastern
#                 Eastern cluster        2013-05-31         Eastern
#                 Eastern cluster        2013-05-28         Eastern
#                 Eastern cluster               NaN         Eastern
#                 Eastern cluster        2013-04-26         Eastern
# Family A        Family A                      NaN          Riyadh
#                 Family A                      NaN             NaN
#                 Family A                      NaN             NaN
# Family B        Family B               2013-03-19             NaN
#                 Family B               2013-02-17             NaN
# Family C        Family C                      NaN             NaN
#                 Family C                      NaN             NaN
#                 Family C               2013-05-10             NaN
# Family D        Family D               2013-08-17  Hafar Al-batin
#                 Family D                      NaN  Hafar Al-batin
#                 Family D                      NaN  Hafar Al-batin
#                 Family D                      NaN  Hafar Al-batin
#                 Family D                      NaN  Hafar Al-batin
# Group 2         Group 2                2013-03-02          Riyadh
#                 Group 2                       NaN          Riyadh
#                 Group 2                2013-02-24          Riyadh
# Group 6         Group 6                       NaN             NaN
# Group A         Group A                       NaN            Asir
#                 Group A                       NaN            Asir
# Hospital B      Hospital B                    NaN             NaN
#                 Hospital B                    NaN             NaN
# Hospital C      Hospital C                    NaN            Taif
#                 Hospital C                    NaN            Taif
#                 Hospital C                    NaN            Taif
# UAE Hospital    UAE Hospital                  NaN             NaN
#                 UAE Hospital                  NaN             NaN
#                 UAE Hospital                  NaN             NaN
#                 UAE Hospital                  NaN             NaN
#                 UAE Hospital                  NaN             NaN
# Unknown 2       Unknown 2                     NaN            Asir
# Unknown 3       Unknown 3                     NaN  Hafar Al-batin
# Unknown 4       Unknown 4                     NaN  Hafar Al-batin
# Unknown 5       Unknown 5                     NaN          Medina
# Unknown 6       Unknown 6                     NaN             NaN
#                 Unknown 6                     NaN             NaN
#                 Unknown 6                     NaN             NaN
#                 Unknown 6                     NaN             NaN
# Unknown 7       Unknown 7                     NaN          Medina
# Unknown 8       Unknown 8                     NaN          Medina
# hospital A      hospital A                    NaN             NaN
#                 hospital A                    NaN    Bisha/Jeddah
#
#                                                                              Notes  \
# Cluster ID      Cluster ID
# Cluster A       Cluster A                                      Travel hx to Jordan
#                 Cluster A                                                      NaN
#                 Cluster A                                                      NaN
# Cluster E       Cluster E                                                      NaN
#                 Cluster E                                                      NaN
#                 Cluster E                                                      NaN
# Eastern cluster Eastern cluster                                                NaN
#                 Eastern cluster                                                NaN
#                 Eastern cluster                                                NaN
#                 Eastern cluster                                                NaN
#                 Eastern cluster                                                NaN
# Family A        Family A                                                       NaN
#                 Family A                                                       NaN
#                 Family A                                                       NaN
# Family B        Family B                                                       NaN
#                 Family B                                                       NaN
# Family C        Family C         Their 66yo father was index case, can't find h...
#                 Family C         Their 66yo father was index case, can't find h...
#                 Family C                                Travel hx to Qatar and KSA
# Family D        Family D                                                       NaN
#                 Family D                                                       NaN
#                 Family D                                                       NaN
#                 Family D                                                       NaN
#                 Family D                                                       NaN
# Group 2         Group 2                                                        NaN
#                 Group 2                                                        NaN
#                 Group 2          Multiple myeloma, diabetes. No hx of contact w...
# Group 6         Group 6                                  Hospital roommate of case
# Group A         Group A                                  Contact w/ previous  case
#                 Group A                                Probably healthcare cluster
# Hospital B      Hospital B                                                     NaN
#                 Hospital B                                                     NaN
# Hospital C      Hospital C       Two of the three cases announced on 6/22 are a...
#                 Hospital C       Two of the three cases announced on 6/22 are a...
#                 Hospital C       Two of the three cases announced on 6/22 are a...
# UAE Hospital    UAE Hospital                                                   NaN
#                 UAE Hospital                                                   NaN
#                 UAE Hospital                                                   NaN
#                 UAE Hospital                                                   NaN
#                 UAE Hospital                                                   NaN
# Unknown 2       Unknown 2                                                      NaN
# Unknown 3       Unknown 3                                                      NaN
# Unknown 4       Unknown 4                                                      NaN
# Unknown 5       Unknown 5                                                      NaN
# Unknown 6       Unknown 6                                                      NaN
#                 Unknown 6                                                      NaN
#                 Unknown 6                                                      NaN
#                 Unknown 6                                                      NaN
# Unknown 7       Unknown 7                                                      NaN
# Unknown 8       Unknown 8                                                      NaN
# hospital A      hospital A                                                     NaN
#                 hospital A                                                     NaN
#
#                                  HCW Reported comorbidities       Cluster ID  \
# Cluster ID      Cluster ID
# Cluster A       Cluster A        NaN                    NaN        Cluster A
#                 Cluster A        NaN                    NaN        Cluster A
#                 Cluster A        NaN                    NaN        Cluster A
# Cluster E       Cluster E          Y                    NaN        Cluster E
#                 Cluster E          Y                    NaN        Cluster E
#                 Cluster E        NaN                      Y        Cluster E
# Eastern cluster Eastern cluster  NaN                      Y  Eastern cluster
#                 Eastern cluster  NaN                      Y  Eastern cluster
#                 Eastern cluster  NaN                      Y  Eastern cluster
#                 Eastern cluster  NaN                      Y  Eastern cluster
#                 Eastern cluster  NaN                      Y  Eastern cluster
# Family A        Family A         NaN                    NaN         Family A
#                 Family A         NaN                    NaN         Family A
#                 Family A         NaN                    NaN         Family A
# Family B        Family B         NaN                    NaN         Family B
#                 Family B         NaN                    NaN         Family B
# Family C        Family C         NaN                    NaN         Family C
#                 Family C         NaN                    NaN         Family C
#                 Family C         NaN                    NaN         Family C
# Family D        Family D         NaN                      Y         Family D
#                 Family D         NaN                    NaN         Family D
#                 Family D         NaN                    NaN         Family D
#                 Family D         NaN                    NaN         Family D
#                 Family D         NaN                    NaN         Family D
# Group 2         Group 2          NaN                    NaN          Group 2
#                 Group 2          NaN                    NaN          Group 2
#                 Group 2          NaN                      Y          Group 2
# Group 6         Group 6          NaN                      Y          Group 6
# Group A         Group A          NaN                    NaN          Group A
#                 Group A            Y                    NaN          Group A
# Hospital B      Hospital B         Y                    NaN       Hospital B
#                 Hospital B         Y                    NaN       Hospital B
# Hospital C      Hospital C         Y                    NaN       Hospital C
#                 Hospital C         Y                    NaN       Hospital C
#                 Hospital C         Y                    NaN       Hospital C
# UAE Hospital    UAE Hospital     NaN                      Y     UAE Hospital
#                 UAE Hospital       Y                    NaN     UAE Hospital
#                 UAE Hospital       Y                    NaN     UAE Hospital
#                 UAE Hospital     NaN                    NaN     UAE Hospital
#                 UAE Hospital     NaN                    NaN     UAE Hospital
# Unknown 2       Unknown 2        NaN                    NaN        Unknown 2
# Unknown 3       Unknown 3        NaN                      Y        Unknown 3
# Unknown 4       Unknown 4        NaN                      Y        Unknown 4
# Unknown 5       Unknown 5        NaN                    NaN        Unknown 5
# Unknown 6       Unknown 6        NaN                    NaN        Unknown 6
#                 Unknown 6          Y                    NaN        Unknown 6
#                 Unknown 6          Y                    NaN        Unknown 6
#                 Unknown 6          Y                    NaN        Unknown 6
# Unknown 7       Unknown 7        NaN                      Y        Unknown 7
# Unknown 8       Unknown 8        NaN                    NaN        Unknown 8
# hospital A      hospital A       NaN                    NaN       hospital A
#                 hospital A       NaN                    NaN       hospital A
#
#                                           onset_date          report_date  \
# Cluster ID      Cluster ID
# Cluster A       Cluster A                        NaN  2013-05-31 00:00:00
#                 Cluster A                        NaN  2013-06-01 00:00:00
#                 Cluster A                        NaN  2013-06-01 00:00:00
# Cluster E       Cluster E        2013-09-01 00:00:00                  NaN
#                 Cluster E        2013-08-15 00:00:00                  NaN
#                 Cluster E        2013-08-21 00:00:00                  NaN
# Eastern cluster Eastern cluster  2013-04-14 00:00:00                  NaN
#                 Eastern cluster  2013-04-17 00:00:00                  NaN
#                 Eastern cluster  2013-04-17 00:00:00                  NaN
#                 Eastern cluster  2013-04-22 00:00:00                  NaN
#                 Eastern cluster  2013-04-22 00:00:00                  NaN
# Family A        Family A         2012-11-05 00:00:00                  NaN
#                 Family A         2012-10-28 00:00:00                  NaN
#                 Family A         2012-10-01 00:00:00                  NaN
# Family B        Family B         2013-01-24 00:00:00                  NaN
#                 Family B         2013-02-06 00:00:00                  NaN
# Family C        Family C                         NaN  2013-04-20 00:00:00
#                 Family C                         NaN  2013-04-20 00:00:00
#                 Family C         2013-05-01 00:00:00                  NaN
# Family D        Family D         2013-08-08 00:00:00                  NaN
#                 Family D                         NaN  2013-08-30 00:00:00
#                 Family D                         NaN  2013-08-30 00:00:00
#                 Family D                         NaN  2013-09-01 00:00:00
#                 Family D                         NaN  2013-09-01 00:00:00
# Group 2         Group 2          2013-02-24 00:00:00                  NaN
#                 Group 2          2013-03-02 00:00:00                  NaN
#                 Group 2          2013-01-30 00:00:00                  NaN
# Group 6         Group 6          2013-04-27 00:00:00                  NaN
# Group A         Group A                          NaN  2013-07-17 00:00:00
#                 Group A                          NaN  2013-07-17 00:00:00
# Hospital B      Hospital B       2013-05-02 00:00:00                  NaN
#                 Hospital B       2013-05-08 00:00:00                  NaN
# Hospital C      Hospital C                       NaN  2013-06-22 00:00:00
#                 Hospital C                       NaN  2013-06-22 00:00:00
#                 Hospital C                       NaN  2013-06-22 00:00:00
# UAE Hospital    UAE Hospital                     NaN  2013-07-12 00:00:00
#                 UAE Hospital                     NaN  2013-07-18 00:00:00
#                 UAE Hospital                     NaN  2013-07-18 00:00:00
#                 UAE Hospital                     NaN  2013-07-18 00:00:00
#                 UAE Hospital                     NaN  2013-07-18 00:00:00
# Unknown 2       Unknown 2                        NaN  2013-08-22 00:00:00
# Unknown 3       Unknown 3        2013-08-23 00:00:00                  NaN
# Unknown 4       Unknown 4                        NaN  2013-09-08 00:00:00
# Unknown 5       Unknown 5                        NaN  2013-09-08 00:00:00
# Unknown 6       Unknown 6                        NaN  2013-09-11 00:00:00
#                 Unknown 6                        NaN  2013-09-11 00:00:00
#                 Unknown 6                        NaN  2013-09-11 00:00:00
#                 Unknown 6                        NaN  2013-09-11 00:00:00
# Unknown 7       Unknown 7                        NaN  2013-09-18 00:00:00
# Unknown 8       Unknown 8                        NaN  2013-09-18 00:00:00
# hospital A      hospital A       2012-04-01 00:00:00                  NaN
#                 hospital A       2012-04-01 00:00:00                  NaN
#
#                                               dates
# Cluster ID      Cluster ID
# Cluster A       Cluster A       2013-05-31 00:00:00
#                 Cluster A       2013-06-01 00:00:00
#                 Cluster A       2013-06-01 00:00:00
# Cluster E       Cluster E       2013-09-01 00:00:00
#                 Cluster E       2013-08-15 00:00:00
#                 Cluster E       2013-08-21 00:00:00
# Eastern cluster Eastern cluster 2013-04-14 00:00:00
#                 Eastern cluster 2013-04-17 00:00:00
#                 Eastern cluster 2013-04-17 00:00:00
#                 Eastern cluster 2013-04-22 00:00:00
#                 Eastern cluster 2013-04-22 00:00:00
# Family A        Family A        2012-11-05 00:00:00
#                 Family A        2012-10-28 00:00:00
#                 Family A        2012-10-01 00:00:00
# Family B        Family B        2013-01-24 00:00:00
#                 Family B        2013-02-06 00:00:00
# Family C        Family C        2013-04-20 00:00:00
#                 Family C        2013-04-20 00:00:00
#                 Family C        2013-05-01 00:00:00
# Family D        Family D        2013-08-08 00:00:00
#                 Family D        2013-08-30 00:00:00
#                 Family D        2013-08-30 00:00:00
#                 Family D        2013-09-01 00:00:00
#                 Family D        2013-09-01 00:00:00
# Group 2         Group 2         2013-02-24 00:00:00
#                 Group 2         2013-03-02 00:00:00
#                 Group 2         2013-01-30 00:00:00
# Group 6         Group 6         2013-04-27 00:00:00
# Group A         Group A         2013-07-17 00:00:00
#                 Group A         2013-07-17 00:00:00
# Hospital B      Hospital B      2013-05-02 00:00:00
#                 Hospital B      2013-05-08 00:00:00
# Hospital C      Hospital C      2013-06-22 00:00:00
#                 Hospital C      2013-06-22 00:00:00
#                 Hospital C      2013-06-22 00:00:00
# UAE Hospital    UAE Hospital    2013-07-12 00:00:00
#                 UAE Hospital    2013-07-18 00:00:00
#                 UAE Hospital    2013-07-18 00:00:00
#                 UAE Hospital    2013-07-18 00:00:00
#                 UAE Hospital    2013-07-18 00:00:00
# Unknown 2       Unknown 2       2013-08-22 00:00:00
# Unknown 3       Unknown 3       2013-08-23 00:00:00
# Unknown 4       Unknown 4       2013-09-08 00:00:00
# Unknown 5       Unknown 5       2013-09-08 00:00:00
# Unknown 6       Unknown 6       2013-09-11 00:00:00
#                 Unknown 6       2013-09-11 00:00:00
#                 Unknown 6       2013-09-11 00:00:00
#                 Unknown 6       2013-09-11 00:00:00
# Unknown 7       Unknown 7       2013-09-18 00:00:00
# Unknown 8       Unknown 8       2013-09-18 00:00:00
# hospital A      hospital A      2012-04-01 00:00:00
#                 hospital A      2012-04-01 00:00:00

# %%
mx.save('./network.pkl')

# %%
def plot_cluster():
    fig, ax = plt.subplots()
    fig.set_size_inches(8, 5)
    ax.xaxis_date()
    ax.set_aspect('auto')
    axprop =  plt.axis()
    fig.autofmt_xdate()
    
    plt.ylim(1, len(grpnames))
    plt.yticks(np.arange(len(grpnames)), grpnames)
    
    for key, group in clusters:
        for date in date_lst:
            xtog = timedelta(((10*axprop[1]-axprop[0])/axprop[1]), 0, 0)
            x1 = [date, date+xtog]
    
            for i in range(len(grpnames)):
                if key == grpnames[i]:
                    y1 = np.array([i, i])
                    y2 = y1+0.5
                    plt.fill_between(x1, y1, y2, color=color, alpha=.3)
                    
                    xspot= x1[0] + timedelta((x1[1] - x1[0]).days/2.0, 0, 0)
                    
                    plt.text(xspot, y1[1]+.25, next(casenums), horizontalalignment='center', verticalalignment='center', fontsize=9)
                    
    return fig
